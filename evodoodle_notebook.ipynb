# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import geonomics as gnx
from evodoodle import init_mod, draw_landscape, edit_landscape, plot_popgen, plot_landscapes
from gnx_params import params
# Out:
# NOTE: Module 'pykrige' not found. Yosemite demo 3d plots cannot be produced.
# pygame 2.6.0 (SDL 2.28.4, Python 3.6.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### 1. Draw your own landscape

# %%
# Draw your landscape carrying capacity
# When you run this chunk a pop-up will appear where you can draw on your own landscape
# Note: d sets the dimensions of your square landscape in terms of the number of cells
population_size = draw_landscape(d = 10)

# %%
# Draw your landscape connectivity
connectivity = draw_landscape(d = 10)

# %%
# Draw your environment for local adaptation
environment = draw_landscape(d = 10)

# %%
# %matplotlib inline
# You can plot all your landscapes using plot_landscapes()
plot_landscapes(population_size, connectivity, environment)

# %%
# If you want to change something, you can edit your landscapes using the edit_landscape() function
environment = edit_landscape(environment)

# %%
# Finally, you can optionally save your landscapes
np.savetxt('population_size.csv', population_size, delimiter=',')
np.savetxt('connectivity.csv', connectivity, delimiter=',')
np.savetxt('environment.csv', environment, delimiter=',')

# Read in landscapes
#population_size = np.loadtxt('population_size.csv', delimiter=',')
#connectivity = np.loadtxt('connectivity.csv', delimiter=',')
#environment = np.loadtxt('environment.csv', delimiter=',')

# %% [markdown]
# ### 2. Play out evolution across your landscape

# %%
# Start model
mod = init_mod(params, population_size, connectivity, environment)
# Out:
# MAKING MODEL...
#
# 	MAKING LANDSCAPE...
#
# 	MAKING COMMUNITY...
#
# 		MAKING SPECIES spp_0...
#
# 			making genomic architecture...
#
# 			making individuals...
#
# 			making movement surface...
# 				[can take a bit]
#
#
#
# No mod.burn_fn_queue was found. Running mod.reset()...
#
#
# Creating the burn-in function queue...
#
#
# Creating the main function queue...
#
#
# burn:	it=-1:	t=0
# 	species: spp_0                         N=462	(births=106	deaths=144)
#
# 	........................................................................
# burn:	it=-1:	t=1
# 	species: spp_0                         N=424	(births=98	deaths=136)
#
# 	........................................................................
# burn:	it=-1:	t=2
# 	species: spp_0                         N=399	(births=84	deaths=109)
#
# 	........................................................................
# burn:	it=-1:	t=3
# 	species: spp_0                         N=363	(births=69	deaths=105)
#
# 	........................................................................
# burn:	it=-1:	t=4
# 	species: spp_0                         N=350	(births=82	deaths=95)
#
# 	........................................................................
# burn:	it=-1:	t=5
# 	species: spp_0                         N=357	(births=68	deaths=61)
#
# 	........................................................................
# burn:	it=-1:	t=6
# 	species: spp_0                         N=327	(births=62	deaths=92)
#
# 	........................................................................
# burn:	it=-1:	t=7
# 	species: spp_0                         N=339	(births=56	deaths=44)
#
# 	........................................................................
# burn:	it=-1:	t=8
# 	species: spp_0                         N=333	(births=71	deaths=77)
#
# 	........................................................................
# burn:	it=-1:	t=9
# 	species: spp_0                         N=325	(births=63	deaths=71)
#
# 	........................................................................
# burn:	it=-1:	t=10
# 	species: spp_0                         N=333	(births=47	deaths=39)
#
# 	........................................................................
# burn:	it=-1:	t=11
# 	species: spp_0                         N=354	(births=67	deaths=46)
#
# 	........................................................................
# burn:	it=-1:	t=12
# 	species: spp_0                         N=349	(births=70	deaths=75)
#
# 	........................................................................
# burn:	it=-1:	t=13
# 	species: spp_0                         N=333	(births=68	deaths=84)
#
# 	........................................................................
# burn:	it=-1:	t=14
# 	species: spp_0                         N=320	(births=77	deaths=90)
#
# 	........................................................................
# burn:	it=-1:	t=15
# 	species: spp_0                         N=319	(births=59	deaths=60)
#
# 	........................................................................
# burn:	it=-1:	t=16
# 	species: spp_0                         N=319	(births=53	deaths=53)
#
# 	........................................................................
# burn:	it=-1:	t=17
# 	species: spp_0                         N=320	(births=60	deaths=59)
#
# 	........................................................................
# burn:	it=-1:	t=18
# 	species: spp_0                         N=322	(births=58	deaths=56)
#
# 	........................................................................
# burn:	it=-1:	t=19
# 	species: spp_0                         N=315	(births=63	deaths=70)
#
# 	........................................................................
# burn:	it=-1:	t=20
# 	species: spp_0                         N=333	(births=61	deaths=43)
#
# 	........................................................................
# burn:	it=-1:	t=21
# 	species: spp_0                         N=333	(births=66	deaths=66)
#
# 	........................................................................
# burn:	it=-1:	t=22
# 	species: spp_0                         N=326	(births=62	deaths=69)
#
# 	........................................................................
# burn:	it=-1:	t=23
# 	species: spp_0                         N=310	(births=57	deaths=73)
#
# 	........................................................................
# burn:	it=-1:	t=24
# 	species: spp_0                         N=299	(births=66	deaths=77)
#
# 	........................................................................
# burn:	it=-1:	t=25
# 	species: spp_0                         N=289	(births=61	deaths=71)
#
# 	........................................................................
# burn:	it=-1:	t=26
# 	species: spp_0                         N=303	(births=64	deaths=50)
#
# 	........................................................................
# burn:	it=-1:	t=27
# 	species: spp_0                         N=327	(births=57	deaths=33)
#
# 	........................................................................
# burn:	it=-1:	t=28
# 	species: spp_0                         N=323	(births=72	deaths=76)
#
# 	........................................................................
# burn:	it=-1:	t=29
# 	species: spp_0                         N=307	(births=74	deaths=90)
#
# 	........................................................................
# burn:	it=-1:	t=30
# 	species: spp_0                         N=318	(births=60	deaths=49)
#
# 	........................................................................
# burn:	it=-1:	t=31
# 	species: spp_0                         N=316	(births=67	deaths=69)
#
# 	........................................................................
# burn:	it=-1:	t=32
# 	species: spp_0                         N=316	(births=68	deaths=68)
#
# 	........................................................................
# burn:	it=-1:	t=33
# 	species: spp_0                         N=333	(births=85	deaths=68)
#
# 	........................................................................
# burn:	it=-1:	t=34
# 	species: spp_0                         N=313	(births=58	deaths=78)
#
# 	........................................................................
# burn:	it=-1:	t=35
# 	species: spp_0                         N=326	(births=74	deaths=61)
#
# 	........................................................................
# burn:	it=-1:	t=36
# 	species: spp_0                         N=315	(births=65	deaths=76)
#
# 	........................................................................
# burn:	it=-1:	t=37
# 	species: spp_0                         N=319	(births=67	deaths=63)
#
# 	........................................................................
# burn:	it=-1:	t=38
# 	species: spp_0                         N=309	(births=57	deaths=67)
#
# 	........................................................................
# burn:	it=-1:	t=39
# 	species: spp_0                         N=321	(births=59	deaths=47)
#
# 	........................................................................
# /home/anushabishop/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# /home/anushabishop/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1510: RuntimeWarning: invalid value encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# /home/anushabishop/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1510: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# burn:	it=-1:	t=40
# 	species: spp_0                         N=312	(births=58	deaths=67)
#
# 	........................................................................
# burn:	it=-1:	t=41
# 	species: spp_0                         N=321	(births=44	deaths=35)
#
# 	........................................................................
# burn:	it=-1:	t=42
# 	species: spp_0                         N=300	(births=59	deaths=80)
#
# 	........................................................................
# burn:	it=-1:	t=43
# 	species: spp_0                         N=309	(births=69	deaths=60)
#
# 	........................................................................
# burn:	it=-1:	t=44
# 	species: spp_0                         N=308	(births=70	deaths=71)
#
# 	........................................................................
# burn:	it=-1:	t=45
# 	species: spp_0                         N=307	(births=55	deaths=56)
#
# 	........................................................................
# burn:	it=-1:	t=46
# 	species: spp_0                         N=320	(births=63	deaths=50)
#
# 	........................................................................
# burn:	it=-1:	t=47
# 	species: spp_0                         N=311	(births=62	deaths=71)
#
# 	........................................................................
# burn:	it=-1:	t=48
# 	species: spp_0                         N=305	(births=65	deaths=71)
#
# 	........................................................................
# burn:	it=-1:	t=49
# 	species: spp_0                         N=296	(births=55	deaths=64)
#
# 	........................................................................
# burn:	it=-1:	t=50
# 	species: spp_0                         N=309	(births=56	deaths=43)
#
# 	........................................................................
# burn:	it=-1:	t=51
# 	species: spp_0                         N=319	(births=65	deaths=55)
#
# 	........................................................................
# burn:	it=-1:	t=52
# 	species: spp_0                         N=314	(births=65	deaths=70)
#
# 	........................................................................
# burn:	it=-1:	t=53
# 	species: spp_0                         N=308	(births=60	deaths=66)
#
# 	........................................................................
# burn:	it=-1:	t=54
# 	species: spp_0                         N=293	(births=63	deaths=78)
#
# 	........................................................................
# burn:	it=-1:	t=55
# 	species: spp_0                         N=292	(births=75	deaths=76)
#
# 	........................................................................
# burn:	it=-1:	t=56
# 	species: spp_0                         N=290	(births=53	deaths=55)
#
# 	........................................................................
# burn:	it=-1:	t=57
# 	species: spp_0                         N=298	(births=57	deaths=49)
#
# 	........................................................................
# burn:	it=-1:	t=58
# 	species: spp_0                         N=315	(births=61	deaths=44)
#
# 	........................................................................
# burn:	it=-1:	t=59
# 	species: spp_0                         N=316	(births=54	deaths=53)
#
# 	........................................................................
# burn:	it=-1:	t=60
# 	species: spp_0                         N=290	(births=72	deaths=98)
#
# 	........................................................................
# burn:	it=-1:	t=61
# 	species: spp_0                         N=298	(births=51	deaths=43)
#
# 	........................................................................
# burn:	it=-1:	t=62
# 	species: spp_0                         N=293	(births=68	deaths=73)
#
# 	........................................................................
# burn:	it=-1:	t=63
# 	species: spp_0                         N=283	(births=58	deaths=68)
#
# 	........................................................................
# burn:	it=-1:	t=64
# 	species: spp_0                         N=294	(births=49	deaths=38)
#
# 	........................................................................
# burn:	it=-1:	t=65
# 	species: spp_0                         N=295	(births=56	deaths=55)
#
# 	........................................................................
# burn:	it=-1:	t=66
# 	species: spp_0                         N=302	(births=79	deaths=72)
#
# 	........................................................................
# burn:	it=-1:	t=67
# 	species: spp_0                         N=308	(births=62	deaths=56)
#
# 	........................................................................
# burn:	it=-1:	t=68
# 	species: spp_0                         N=319	(births=57	deaths=46)
#
# 	........................................................................
# burn:	it=-1:	t=69
# 	species: spp_0                         N=310	(births=52	deaths=61)
#
# 	........................................................................
# burn:	it=-1:	t=70
# 	species: spp_0                         N=319	(births=63	deaths=54)
#
# 	........................................................................
# burn:	it=-1:	t=71
# 	species: spp_0                         N=313	(births=63	deaths=69)
#
# 	........................................................................
# burn:	it=-1:	t=72
# 	species: spp_0                         N=323	(births=65	deaths=55)
#
# 	........................................................................
# burn:	it=-1:	t=73
# 	species: spp_0                         N=316	(births=64	deaths=71)
#
# 	........................................................................
# burn:	it=-1:	t=74
# 	species: spp_0                         N=329	(births=59	deaths=46)
#
# 	........................................................................
# burn:	it=-1:	t=75
# 	species: spp_0                         N=337	(births=70	deaths=62)
#
# 	........................................................................
# burn:	it=-1:	t=76
# 	species: spp_0                         N=318	(births=66	deaths=85)
#
# 	........................................................................
# burn:	it=-1:	t=77
# 	species: spp_0                         N=317	(births=56	deaths=57)
#
# 	........................................................................
# burn:	it=-1:	t=78
# 	species: spp_0                         N=315	(births=67	deaths=69)
#
# 	........................................................................
# burn:	it=-1:	t=79
# 	species: spp_0                         N=303	(births=71	deaths=83)
#
# 	........................................................................
# burn:	it=-1:	t=80
# 	species: spp_0                         N=311	(births=65	deaths=57)
#
# 	........................................................................
# burn:	it=-1:	t=81
# 	species: spp_0                         N=303	(births=71	deaths=79)
#
# 	........................................................................
# burn:	it=-1:	t=82
# 	species: spp_0                         N=310	(births=73	deaths=66)
#
# 	........................................................................
# burn:	it=-1:	t=83
# 	species: spp_0                         N=300	(births=59	deaths=69)
#
# 	........................................................................
# burn:	it=-1:	t=84
# 	species: spp_0                         N=313	(births=58	deaths=45)
#
# 	........................................................................
# burn:	it=-1:	t=85
# 	species: spp_0                         N=314	(births=56	deaths=55)
#
# 	........................................................................
# burn:	it=-1:	t=86
# 	species: spp_0                         N=295	(births=49	deaths=68)
#
# 	........................................................................
# burn:	it=-1:	t=87
# 	species: spp_0                         N=294	(births=64	deaths=65)
#
# 	........................................................................
# burn:	it=-1:	t=88
# 	species: spp_0                         N=309	(births=69	deaths=54)
#
# 	........................................................................
# burn:	it=-1:	t=89
# 	species: spp_0                         N=310	(births=66	deaths=65)
#
# 	........................................................................
# burn:	it=-1:	t=90
# 	species: spp_0                         N=317	(births=63	deaths=56)
#
# 	........................................................................
# burn:	it=-1:	t=91
# 	species: spp_0                         N=315	(births=76	deaths=78)
#
# 	........................................................................
# burn:	it=-1:	t=92
# 	species: spp_0                         N=292	(births=56	deaths=79)
#
# 	........................................................................
#
# Assigning genomes for species "spp_0"...
#
#
# Burn-in complete.

# %%
# Plot initial model (no selection has occurred yet)
plot_popgen(mod)

# %%
# Run the model for 100 timesteps
mod.walk(100)
# Out:
# main:	it=-1:	t=0
# 	species: spp_0                         N=320	(births=52	deaths=53)
#
# 	........................................................................
# main:	it=-1:	t=1
# 	species: spp_0                         N=299	(births=74	deaths=95)
#
# 	........................................................................
# main:	it=-1:	t=2
# 	species: spp_0                         N=310	(births=59	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=3
# 	species: spp_0                         N=297	(births=57	deaths=70)
#
# 	........................................................................
# main:	it=-1:	t=4
# 	species: spp_0                         N=299	(births=53	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=5
# 	species: spp_0                         N=302	(births=80	deaths=77)
#
# 	........................................................................
# main:	it=-1:	t=6
# 	species: spp_0                         N=313	(births=53	deaths=42)
#
# 	........................................................................
# main:	it=-1:	t=7
# 	species: spp_0                         N=288	(births=65	deaths=90)
#
# 	........................................................................
# main:	it=-1:	t=8
# 	species: spp_0                         N=291	(births=65	deaths=62)
#
# 	........................................................................
# main:	it=-1:	t=9
# 	species: spp_0                         N=289	(births=44	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=10
# 	species: spp_0                         N=286	(births=59	deaths=62)
#
# 	........................................................................
# main:	it=-1:	t=11
# 	species: spp_0                         N=276	(births=56	deaths=66)
#
# 	........................................................................
# main:	it=-1:	t=12
# 	species: spp_0                         N=273	(births=49	deaths=52)
#
# 	........................................................................
# main:	it=-1:	t=13
# 	species: spp_0                         N=295	(births=52	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=14
# 	species: spp_0                         N=287	(births=53	deaths=61)
#
# 	........................................................................
# main:	it=-1:	t=15
# 	species: spp_0                         N=282	(births=50	deaths=55)
#
# 	........................................................................
# main:	it=-1:	t=16
# 	species: spp_0                         N=297	(births=71	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=17
# 	species: spp_0                         N=288	(births=68	deaths=77)
#
# 	........................................................................
# main:	it=-1:	t=18
# 	species: spp_0                         N=291	(births=58	deaths=55)
#
# 	........................................................................
# main:	it=-1:	t=19
# 	species: spp_0                         N=282	(births=49	deaths=58)
#
# 	........................................................................
# main:	it=-1:	t=20
# 	species: spp_0                         N=291	(births=41	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=21
# 	species: spp_0                         N=308	(births=57	deaths=40)
#
# 	........................................................................
# main:	it=-1:	t=22
# 	species: spp_0                         N=283	(births=59	deaths=84)
#
# 	........................................................................
# main:	it=-1:	t=23
# 	species: spp_0                         N=282	(births=44	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=24
# 	species: spp_0                         N=282	(births=59	deaths=59)
#
# 	........................................................................
# main:	it=-1:	t=25
# 	species: spp_0                         N=297	(births=62	deaths=47)
#
# 	........................................................................
# main:	it=-1:	t=26
# 	species: spp_0                         N=311	(births=52	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=27
# 	species: spp_0                         N=304	(births=69	deaths=76)
#
# 	........................................................................
# main:	it=-1:	t=28
# 	species: spp_0                         N=307	(births=55	deaths=52)
#
# 	........................................................................
# main:	it=-1:	t=29
# 	species: spp_0                         N=297	(births=68	deaths=78)
#
# 	........................................................................
# main:	it=-1:	t=30
# 	species: spp_0                         N=295	(births=65	deaths=67)
#
# 	........................................................................
# main:	it=-1:	t=31
# 	species: spp_0                         N=310	(births=76	deaths=61)
#
# 	........................................................................
# main:	it=-1:	t=32
# 	species: spp_0                         N=302	(births=54	deaths=62)
#
# 	........................................................................
# main:	it=-1:	t=33
# 	species: spp_0                         N=306	(births=51	deaths=47)
#
# 	........................................................................
# main:	it=-1:	t=34
# 	species: spp_0                         N=300	(births=62	deaths=68)
#
# 	........................................................................
# main:	it=-1:	t=35
# 	species: spp_0                         N=287	(births=68	deaths=81)
#
# 	........................................................................
# main:	it=-1:	t=36
# 	species: spp_0                         N=294	(births=66	deaths=59)
#
# 	........................................................................
# main:	it=-1:	t=37
# 	species: spp_0                         N=302	(births=55	deaths=47)
#
# 	........................................................................
# main:	it=-1:	t=38
# 	species: spp_0                         N=298	(births=59	deaths=63)
#
# 	........................................................................
# main:	it=-1:	t=39
# 	species: spp_0                         N=299	(births=60	deaths=59)
#
# 	........................................................................
# main:	it=-1:	t=40
# 	species: spp_0                         N=290	(births=60	deaths=69)
#
# 	........................................................................
# main:	it=-1:	t=41
# 	species: spp_0                         N=278	(births=61	deaths=73)
#
# 	........................................................................
# main:	it=-1:	t=42
# 	species: spp_0                         N=281	(births=64	deaths=61)
#
# 	........................................................................
# main:	it=-1:	t=43
# 	species: spp_0                         N=279	(births=58	deaths=60)
#
# 	........................................................................
# main:	it=-1:	t=44
# 	species: spp_0                         N=274	(births=46	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=45
# 	species: spp_0                         N=280	(births=57	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=46
# 	species: spp_0                         N=290	(births=58	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=47
# 	species: spp_0                         N=293	(births=51	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=48
# 	species: spp_0                         N=287	(births=56	deaths=62)
#
# 	........................................................................
# main:	it=-1:	t=49
# 	species: spp_0                         N=291	(births=63	deaths=59)
#
# 	........................................................................
# main:	it=-1:	t=50
# 	species: spp_0                         N=280	(births=66	deaths=77)
#
# 	........................................................................
# main:	it=-1:	t=51
# 	species: spp_0                         N=287	(births=64	deaths=57)
#
# 	........................................................................
# main:	it=-1:	t=52
# 	species: spp_0                         N=283	(births=53	deaths=57)
#
# 	........................................................................
# main:	it=-1:	t=53
# 	species: spp_0                         N=279	(births=72	deaths=76)
#
# 	........................................................................
# main:	it=-1:	t=54
# 	species: spp_0                         N=293	(births=64	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=55
# 	species: spp_0                         N=286	(births=61	deaths=68)
#
# 	........................................................................
# main:	it=-1:	t=56
# 	species: spp_0                         N=280	(births=58	deaths=64)
#
# 	........................................................................
# main:	it=-1:	t=57
# 	species: spp_0                         N=292	(births=49	deaths=37)
#
# 	........................................................................
# main:	it=-1:	t=58
# 	species: spp_0                         N=290	(births=63	deaths=65)
#
# 	........................................................................
# main:	it=-1:	t=59
# 	species: spp_0                         N=285	(births=58	deaths=63)
#
# 	........................................................................
# main:	it=-1:	t=60
# 	species: spp_0                         N=291	(births=64	deaths=58)
#
# 	........................................................................
# main:	it=-1:	t=61
# 	species: spp_0                         N=301	(births=59	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=62
# 	species: spp_0                         N=292	(births=76	deaths=85)
#
# 	........................................................................
# main:	it=-1:	t=63
# 	species: spp_0                         N=302	(births=54	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=64
# 	species: spp_0                         N=298	(births=65	deaths=69)
#
# 	........................................................................
# main:	it=-1:	t=65
# 	species: spp_0                         N=288	(births=56	deaths=66)
#
# 	........................................................................
# main:	it=-1:	t=66
# 	species: spp_0                         N=297	(births=59	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=67
# 	species: spp_0                         N=308	(births=66	deaths=55)
#
# 	........................................................................
# main:	it=-1:	t=68
# 	species: spp_0                         N=306	(births=70	deaths=72)
#
# 	........................................................................
# main:	it=-1:	t=69
# 	species: spp_0                         N=310	(births=58	deaths=54)
#
# 	........................................................................
# main:	it=-1:	t=70
# 	species: spp_0                         N=309	(births=47	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=71
# 	species: spp_0                         N=286	(births=61	deaths=84)
#
# 	........................................................................
# main:	it=-1:	t=72
# 	species: spp_0                         N=286	(births=58	deaths=58)
#
# 	........................................................................
# main:	it=-1:	t=73
# 	species: spp_0                         N=292	(births=51	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=74
# 	species: spp_0                         N=284	(births=46	deaths=54)
#
# 	........................................................................
# main:	it=-1:	t=75
# 	species: spp_0                         N=316	(births=73	deaths=41)
#
# 	........................................................................
# main:	it=-1:	t=76
# 	species: spp_0                         N=306	(births=65	deaths=75)
#
# 	........................................................................
# main:	it=-1:	t=77
# 	species: spp_0                         N=302	(births=54	deaths=58)
#
# 	........................................................................
# main:	it=-1:	t=78
# 	species: spp_0                         N=306	(births=57	deaths=53)
#
# 	........................................................................
# main:	it=-1:	t=79
# 	species: spp_0                         N=301	(births=51	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=80
# 	species: spp_0                         N=300	(births=52	deaths=53)
#
# 	........................................................................
# main:	it=-1:	t=81
# 	species: spp_0                         N=298	(births=65	deaths=67)
#
# 	........................................................................
# main:	it=-1:	t=82
# 	species: spp_0                         N=303	(births=53	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=83
# 	species: spp_0                         N=296	(births=49	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=84
# 	species: spp_0                         N=281	(births=60	deaths=75)
#
# 	........................................................................
# main:	it=-1:	t=85
# 	species: spp_0                         N=296	(births=60	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=86
# 	species: spp_0                         N=304	(births=62	deaths=54)
#
# 	........................................................................
# main:	it=-1:	t=87
# 	species: spp_0                         N=315	(births=56	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=88
# 	species: spp_0                         N=326	(births=62	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=89
# 	species: spp_0                         N=330	(births=57	deaths=53)
#
# 	........................................................................
# main:	it=-1:	t=90
# 	species: spp_0                         N=336	(births=71	deaths=65)
#
# 	........................................................................
# main:	it=-1:	t=91
# 	species: spp_0                         N=326	(births=61	deaths=71)
#
# 	........................................................................
# main:	it=-1:	t=92
# 	species: spp_0                         N=330	(births=70	deaths=66)
#
# 	........................................................................
# main:	it=-1:	t=93
# 	species: spp_0                         N=322	(births=63	deaths=71)
#
# 	........................................................................
# main:	it=-1:	t=94
# 	species: spp_0                         N=325	(births=70	deaths=67)
#
# 	........................................................................
# main:	it=-1:	t=95
# 	species: spp_0                         N=326	(births=70	deaths=69)
#
# 	........................................................................
# main:	it=-1:	t=96
# 	species: spp_0                         N=330	(births=76	deaths=72)
#
# 	........................................................................
# main:	it=-1:	t=97
# 	species: spp_0                         N=319	(births=83	deaths=94)
#
# 	........................................................................
# main:	it=-1:	t=98
# 	species: spp_0                         N=306	(births=53	deaths=66)
#
# 	........................................................................
# main:	it=-1:	t=99
# 	species: spp_0                         N=298	(births=59	deaths=67)
#
# 	........................................................................
#
#
# now sorting and simplifying tskit tables for Species: 'spp_0'
# 	NUMBER EDGES BEFORE SIMPLIFICATION: 4927
# 	NUMBER INDIVIDS BEFORE SIMPLIFICATION: 823
#
# 	NUMBER EDGES AFTER SIMPLIFICATION:  4927
# 	NUMBER INDIVIDS AFTER SIMPLIFICATION:  823

# %%
# Plot the results
plot_popgen(mod)

# %%
# Run the model for another 100 steps
mod.walk(100)
# Out:
# main:	it=-1:	t=0
# 	species: spp_0                         N=1397	(births=292	deaths=365)
#
# 	........................................................................
# main:	it=-1:	t=1
# 	species: spp_0                         N=1377	(births=264	deaths=284)
#
# 	........................................................................
# main:	it=-1:	t=2
# 	species: spp_0                         N=1399	(births=280	deaths=258)
#
# 	........................................................................
# main:	it=-1:	t=3
# 	species: spp_0                         N=1396	(births=280	deaths=283)
#
# 	........................................................................
# main:	it=-1:	t=4
# 	species: spp_0                         N=1407	(births=261	deaths=250)
#
# 	........................................................................
# main:	it=-1:	t=5
# 	species: spp_0                         N=1433	(births=276	deaths=250)
#
# 	........................................................................
# main:	it=-1:	t=6
# 	species: spp_0                         N=1416	(births=322	deaths=339)
#
# 	........................................................................
# main:	it=-1:	t=7
# 	species: spp_0                         N=1407	(births=279	deaths=288)
#
# 	........................................................................
# main:	it=-1:	t=8
# 	species: spp_0                         N=1408	(births=271	deaths=270)
#
# 	........................................................................
# main:	it=-1:	t=9
# 	species: spp_0                         N=1431	(births=248	deaths=225)
#
# 	........................................................................

# %%
plot_popgen(mod)

# %% [markdown]
# ### Challenges

# %% [markdown]
# 1. You are consulting with a conservation organization that is trying to decide whether to build (Option 1) a large, connected, single preserve or (Option 2) several, smaller, disconnected preserves. Design a simulation (or a set of simulations) to help them make their decision. Bonus challenge: try and simulate one scenario where option (1) is best and one scenario where (2) is best (Hint: think about different things you might want to conserve)
#
# 2. Wildlife corridors are a popular method for restoring connectivity between areas fragmented by human development, such as roads. Create a simulation (or a pair of simulations) that shows the effect of a wildlife corridor across a hypothetical road on genetic diversity. What happens if the corridor connects two very different environments?
#
# 3. Your friend comes to you super excited because they just analyzed their landscape genetics data on hedgehogs and found a super clear gradient in PC values that aligns with a gradient in temperature [IMAGE]. They tell you that they think this is an indication that hedgehogs are locally adapted to temperature. What do you think? Can you come up with a simulation to show your friend what else could be causing this pattern?
#
# 4. [SHOW IMAGE] try and create a simulation that matches the plot below. Bonus challenge: can you generate two different simulations that produce the same plot?
