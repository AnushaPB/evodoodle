# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import geonomics as gnx
from evodoodle import init_mod, draw_landscape, edit_landscape, plot_popgen, plot_landscapes
from gnx_params import params
# Out:
# NOTE: No display found. Using non-interactive Agg backend
#
# NOTE: Module 'pykrige' not found. Yosemite demo 3d plots cannot be produced.
# pygame 2.5.2 (SDL 2.28.3, Python 3.8.19)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### 1. Draw your own landscape

# %%
# Draw your landscape carrying capacity
# When you run this chunk a pop-up will appear where you can draw on your own landscape
# Note: d sets the dimensions of your square landscape in terms of the number of cells
population_size = draw_landscape(d = 10)

# %%
# Draw your landscape connectivity
connectivity = draw_landscape(d = 10)

# %%
# Draw your environment for local adaptation
environment = draw_landscape(d = 10)

# %%
# %matplotlib inline
# You can plot all your landscapes using plot_landscapes()
plot_landscapes(population_size, connectivity, environment)

# %%
# If you want to change something, you can edit your landscapes using the edit_landscape() function
environment = edit_landscape(environment)

# %%
# Finally, you can optionally save your landscapes
np.savetxt('population_size.csv', population_size, delimiter=',')
np.savetxt('connectivity.csv', connectivity, delimiter=',')
np.savetxt('environment.csv', environment, delimiter=',')

# Read in landscapes
#population_size = np.loadtxt('population_size.csv', delimiter=',')
#connectivity = np.loadtxt('connectivity.csv', delimiter=',')
#environment = np.loadtxt('environment.csv', delimiter=',')

# %% [markdown]
# ### 2. Play out evolution across your landscape

# %%
# Start model
mod = init_mod(params, population_size, connectivity, environment)
# Out:
# MAKING MODEL...
#
# 	MAKING LANDSCAPE...
#
# 	MAKING COMMUNITY...
#
# 		MAKING SPECIES spp_0...
#
# 			making genomic architecture...
#
# 			making individuals...
#
# 			making movement surface...
# 				[can take a bit]
#
#
#
# No mod.burn_fn_queue was found. Running mod.reset()...
#
#
# Creating the burn-in function queue...
#
#
# Creating the main function queue...
#
#
# burn:	it=-1:	t=0
# 	species: spp_0                         N=347	(births=114	deaths=267)
#
# 	........................................................................
# burn:	it=-1:	t=1
# 	species: spp_0                         N=316	(births=69	deaths=100)
#
# 	........................................................................
# burn:	it=-1:	t=2
# 	species: spp_0                         N=313	(births=58	deaths=61)
#
# 	........................................................................
# burn:	it=-1:	t=3
# 	species: spp_0                         N=295	(births=57	deaths=75)
#
# 	........................................................................
# burn:	it=-1:	t=4
# 	species: spp_0                         N=290	(births=64	deaths=69)
#
# 	........................................................................
# burn:	it=-1:	t=5
# 	species: spp_0                         N=268	(births=51	deaths=73)
#
# 	........................................................................
# burn:	it=-1:	t=6
# 	species: spp_0                         N=265	(births=42	deaths=45)
#
# 	........................................................................
# burn:	it=-1:	t=7
# 	species: spp_0                         N=274	(births=56	deaths=47)
#
# 	........................................................................
# burn:	it=-1:	t=8
# 	species: spp_0                         N=272	(births=52	deaths=54)
#
# 	........................................................................
# burn:	it=-1:	t=9
# 	species: spp_0                         N=266	(births=49	deaths=55)
#
# 	........................................................................
# burn:	it=-1:	t=10
# 	species: spp_0                         N=272	(births=40	deaths=34)
#
# 	........................................................................
# burn:	it=-1:	t=11
# 	species: spp_0                         N=249	(births=47	deaths=70)
#
# 	........................................................................
# burn:	it=-1:	t=12
# 	species: spp_0                         N=256	(births=51	deaths=44)
#
# 	........................................................................
# burn:	it=-1:	t=13
# 	species: spp_0                         N=259	(births=53	deaths=50)
#
# 	........................................................................
# burn:	it=-1:	t=14
# 	species: spp_0                         N=252	(births=38	deaths=45)
#
# 	........................................................................
# burn:	it=-1:	t=15
# 	species: spp_0                         N=254	(births=60	deaths=58)
#
# 	........................................................................
# burn:	it=-1:	t=16
# 	species: spp_0                         N=253	(births=52	deaths=53)
#
# 	........................................................................
# burn:	it=-1:	t=17
# 	species: spp_0                         N=268	(births=55	deaths=40)
#
# 	........................................................................
# burn:	it=-1:	t=18
# 	species: spp_0                         N=255	(births=53	deaths=66)
#
# 	........................................................................
# burn:	it=-1:	t=19
# 	species: spp_0                         N=250	(births=53	deaths=58)
#
# 	........................................................................
# burn:	it=-1:	t=20
# 	species: spp_0                         N=258	(births=51	deaths=43)
#
# 	........................................................................
# burn:	it=-1:	t=21
# 	species: spp_0                         N=254	(births=45	deaths=49)
#
# 	........................................................................
# burn:	it=-1:	t=22
# 	species: spp_0                         N=249	(births=56	deaths=61)
#
# 	........................................................................
# burn:	it=-1:	t=23
# 	species: spp_0                         N=256	(births=49	deaths=42)
#
# 	........................................................................
# burn:	it=-1:	t=24
# 	species: spp_0                         N=267	(births=57	deaths=46)
#
# 	........................................................................
# burn:	it=-1:	t=25
# 	species: spp_0                         N=259	(births=55	deaths=63)
#
# 	........................................................................
# burn:	it=-1:	t=26
# 	species: spp_0                         N=274	(births=51	deaths=36)
#
# 	........................................................................
# burn:	it=-1:	t=27
# 	species: spp_0                         N=265	(births=53	deaths=62)
#
# 	........................................................................
# burn:	it=-1:	t=28
# 	species: spp_0                         N=268	(births=54	deaths=51)
#
# 	........................................................................
# burn:	it=-1:	t=29
# 	species: spp_0                         N=261	(births=51	deaths=58)
#
# 	........................................................................
# burn:	it=-1:	t=30
# 	species: spp_0                         N=237	(births=56	deaths=80)
#
# 	........................................................................
# burn:	it=-1:	t=31
# 	species: spp_0                         N=239	(births=54	deaths=52)
#
# 	........................................................................
# burn:	it=-1:	t=32
# 	species: spp_0                         N=240	(births=49	deaths=48)
#
# 	........................................................................
# burn:	it=-1:	t=33
# 	species: spp_0                         N=246	(births=49	deaths=43)
#
# 	........................................................................
# burn:	it=-1:	t=34
# 	species: spp_0                         N=241	(births=47	deaths=52)
#
# 	........................................................................
# burn:	it=-1:	t=35
# 	species: spp_0                         N=245	(births=48	deaths=44)
#
# 	........................................................................
# burn:	it=-1:	t=36
# 	species: spp_0                         N=245	(births=40	deaths=40)
#
# 	........................................................................
# burn:	it=-1:	t=37
# 	species: spp_0                         N=241	(births=44	deaths=48)
#
# 	........................................................................
# burn:	it=-1:	t=38
# 	species: spp_0                         N=239	(births=49	deaths=51)
#
# 	........................................................................
# burn:	it=-1:	t=39
# 	species: spp_0                         N=235	(births=53	deaths=57)
#
# 	........................................................................
# burn:	it=-1:	t=40
# 	species: spp_0                         N=253	(births=42	deaths=24)
#
# 	........................................................................
# burn:	it=-1:	t=41
# 	species: spp_0                         N=257	(births=44	deaths=40)
#
# 	........................................................................
# burn:	it=-1:	t=42
# 	species: spp_0                         N=259	(births=58	deaths=56)
#
# 	........................................................................
# burn:	it=-1:	t=43
# 	species: spp_0                         N=243	(births=59	deaths=75)
#
# 	........................................................................
# burn:	it=-1:	t=44
# 	species: spp_0                         N=254	(births=49	deaths=38)
#
# 	........................................................................
# burn:	it=-1:	t=45
# 	species: spp_0                         N=259	(births=64	deaths=59)
#
# 	........................................................................
# burn:	it=-1:	t=46
# 	species: spp_0                         N=245	(births=47	deaths=61)
#
# 	........................................................................
# burn:	it=-1:	t=47
# 	species: spp_0                         N=248	(births=37	deaths=34)
#
# 	........................................................................
# burn:	it=-1:	t=48
# 	species: spp_0                         N=252	(births=32	deaths=28)
#
# 	........................................................................
# burn:	it=-1:	t=49
# 	species: spp_0                         N=246	(births=43	deaths=49)
#
# 	........................................................................
# burn:	it=-1:	t=50
# 	species: spp_0                         N=237	(births=37	deaths=46)
#
# 	........................................................................
# burn:	it=-1:	t=51
# 	species: spp_0                         N=245	(births=49	deaths=41)
#
# 	........................................................................
# burn:	it=-1:	t=52
# 	species: spp_0                         N=241	(births=57	deaths=61)
#
# 	........................................................................
# burn:	it=-1:	t=53
# 	species: spp_0                         N=238	(births=45	deaths=48)
#
# 	........................................................................
# burn:	it=-1:	t=54
# 	species: spp_0                         N=236	(births=48	deaths=50)
#
# 	........................................................................
# burn:	it=-1:	t=55
# 	species: spp_0                         N=237	(births=51	deaths=50)
#
# 	........................................................................
# burn:	it=-1:	t=56
# 	species: spp_0                         N=244	(births=41	deaths=34)
#
# 	........................................................................
# burn:	it=-1:	t=57
# 	species: spp_0                         N=257	(births=48	deaths=35)
#
# 	........................................................................
#
# Assigning genomes for species "spp_0"...
#
#
# Burn-in complete.

# %%
# Plot initial model (no selection has occurred yet)
plot_popgen(mod)

# %%
# Run the model for 100 timesteps
mod.walk(100)
# Out:
# main:	it=-1:	t=0
# 	species: spp_0                         N=232	(births=36	deaths=61)
#
# 	........................................................................
# main:	it=-1:	t=1
# 	species: spp_0                         N=220	(births=38	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=2
# 	species: spp_0                         N=225	(births=47	deaths=42)
#
# 	........................................................................
# main:	it=-1:	t=3
# 	species: spp_0                         N=228	(births=45	deaths=42)
#
# 	........................................................................
# main:	it=-1:	t=4
# 	species: spp_0                         N=234	(births=42	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=5
# 	species: spp_0                         N=226	(births=54	deaths=62)
#
# 	........................................................................
# main:	it=-1:	t=6
# 	species: spp_0                         N=227	(births=45	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=7
# 	species: spp_0                         N=245	(births=49	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=8
# 	species: spp_0                         N=244	(births=51	deaths=52)
#
# 	........................................................................
# main:	it=-1:	t=9
# 	species: spp_0                         N=247	(births=64	deaths=61)
#
# 	........................................................................
# main:	it=-1:	t=10
# 	species: spp_0                         N=245	(births=56	deaths=58)
#
# 	........................................................................
# main:	it=-1:	t=11
# 	species: spp_0                         N=238	(births=45	deaths=52)
#
# 	........................................................................
# main:	it=-1:	t=12
# 	species: spp_0                         N=229	(births=47	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=13
# 	species: spp_0                         N=230	(births=39	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=14
# 	species: spp_0                         N=235	(births=51	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=15
# 	species: spp_0                         N=216	(births=45	deaths=64)
#
# 	........................................................................
# main:	it=-1:	t=16
# 	species: spp_0                         N=217	(births=34	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=17
# 	species: spp_0                         N=220	(births=52	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=18
# 	species: spp_0                         N=231	(births=38	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=19
# 	species: spp_0                         N=232	(births=47	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=20
# 	species: spp_0                         N=235	(births=38	deaths=35)
#
# 	........................................................................
# main:	it=-1:	t=21
# 	species: spp_0                         N=248	(births=48	deaths=35)
#
# 	........................................................................
# main:	it=-1:	t=22
# 	species: spp_0                         N=247	(births=51	deaths=52)
#
# 	........................................................................
# main:	it=-1:	t=23
# 	species: spp_0                         N=231	(births=46	deaths=62)
#
# 	........................................................................
# main:	it=-1:	t=24
# 	species: spp_0                         N=239	(births=49	deaths=41)
#
# 	........................................................................
# main:	it=-1:	t=25
# 	species: spp_0                         N=233	(births=36	deaths=42)
#
# 	........................................................................
# main:	it=-1:	t=26
# 	species: spp_0                         N=220	(births=43	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=27
# 	species: spp_0                         N=236	(births=45	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=28
# 	species: spp_0                         N=241	(births=54	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=29
# 	species: spp_0                         N=241	(births=42	deaths=42)
#
# 	........................................................................
# main:	it=-1:	t=30
# 	species: spp_0                         N=242	(births=52	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=31
# 	species: spp_0                         N=257	(births=60	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=32
# 	species: spp_0                         N=247	(births=43	deaths=53)
#
# 	........................................................................
# main:	it=-1:	t=33
# 	species: spp_0                         N=227	(births=43	deaths=63)
#
# 	........................................................................
# main:	it=-1:	t=34
# 	species: spp_0                         N=223	(births=44	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=35
# 	species: spp_0                         N=223	(births=49	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=36
# 	species: spp_0                         N=219	(births=46	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=37
# 	species: spp_0                         N=219	(births=39	deaths=39)
#
# 	........................................................................
# main:	it=-1:	t=38
# 	species: spp_0                         N=207	(births=52	deaths=64)
#
# 	........................................................................
# main:	it=-1:	t=39
# 	species: spp_0                         N=221	(births=53	deaths=39)
#
# 	........................................................................
# main:	it=-1:	t=40
# 	species: spp_0                         N=226	(births=39	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=41
# 	species: spp_0                         N=229	(births=46	deaths=43)
#
# 	........................................................................
# main:	it=-1:	t=42
# 	species: spp_0                         N=236	(births=47	deaths=40)
#
# 	........................................................................
# main:	it=-1:	t=43
# 	species: spp_0                         N=241	(births=55	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=44
# 	species: spp_0                         N=236	(births=56	deaths=61)
#
# 	........................................................................
# main:	it=-1:	t=45
# 	species: spp_0                         N=224	(births=52	deaths=64)
#
# 	........................................................................
# main:	it=-1:	t=46
# 	species: spp_0                         N=226	(births=52	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=47
# 	species: spp_0                         N=236	(births=47	deaths=37)
#
# 	........................................................................
# main:	it=-1:	t=48
# 	species: spp_0                         N=253	(births=61	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=49
# 	species: spp_0                         N=248	(births=58	deaths=63)
#
# 	........................................................................
# main:	it=-1:	t=50
# 	species: spp_0                         N=241	(births=49	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=51
# 	species: spp_0                         N=239	(births=48	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=52
# 	species: spp_0                         N=233	(births=45	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=53
# 	species: spp_0                         N=234	(births=53	deaths=52)
#
# 	........................................................................
# main:	it=-1:	t=54
# 	species: spp_0                         N=237	(births=54	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=55
# 	species: spp_0                         N=230	(births=43	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=56
# 	species: spp_0                         N=234	(births=42	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=57
# 	species: spp_0                         N=251	(births=47	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=58
# 	species: spp_0                         N=242	(births=57	deaths=66)
#
# 	........................................................................
# main:	it=-1:	t=59
# 	species: spp_0                         N=239	(births=44	deaths=47)
#
# 	........................................................................
# main:	it=-1:	t=60
# 	species: spp_0                         N=233	(births=54	deaths=60)
#
# 	........................................................................
# main:	it=-1:	t=61
# 	species: spp_0                         N=240	(births=55	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=62
# 	species: spp_0                         N=233	(births=41	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=63
# 	species: spp_0                         N=236	(births=47	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=64
# 	species: spp_0                         N=240	(births=39	deaths=35)
#
# 	........................................................................
# main:	it=-1:	t=65
# 	species: spp_0                         N=239	(births=42	deaths=43)
#
# 	........................................................................
# main:	it=-1:	t=66
# 	species: spp_0                         N=246	(births=39	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=67
# 	species: spp_0                         N=241	(births=46	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=68
# 	species: spp_0                         N=234	(births=53	deaths=60)
#
# 	........................................................................
# main:	it=-1:	t=69
# 	species: spp_0                         N=217	(births=34	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=70
# 	species: spp_0                         N=203	(births=36	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=71
# 	species: spp_0                         N=207	(births=38	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=72
# 	species: spp_0                         N=203	(births=41	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=73
# 	species: spp_0                         N=202	(births=40	deaths=41)
#
# 	........................................................................
# main:	it=-1:	t=74
# 	species: spp_0                         N=208	(births=48	deaths=42)
#
# 	........................................................................
# main:	it=-1:	t=75
# 	species: spp_0                         N=210	(births=42	deaths=40)
#
# 	........................................................................
# main:	it=-1:	t=76
# 	species: spp_0                         N=217	(births=42	deaths=35)
#
# 	........................................................................
# main:	it=-1:	t=77
# 	species: spp_0                         N=217	(births=40	deaths=40)
#
# 	........................................................................
# main:	it=-1:	t=78
# 	species: spp_0                         N=217	(births=41	deaths=41)
#
# 	........................................................................
# main:	it=-1:	t=79
# 	species: spp_0                         N=212	(births=43	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=80
# 	species: spp_0                         N=211	(births=37	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=81
# 	species: spp_0                         N=221	(births=42	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=82
# 	species: spp_0                         N=223	(births=49	deaths=47)
#
# 	........................................................................
# main:	it=-1:	t=83
# 	species: spp_0                         N=233	(births=44	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=84
# 	species: spp_0                         N=239	(births=53	deaths=47)
#
# 	........................................................................
# main:	it=-1:	t=85
# 	species: spp_0                         N=241	(births=46	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=86
# 	species: spp_0                         N=239	(births=51	deaths=53)
#
# 	........................................................................
# main:	it=-1:	t=87
# 	species: spp_0                         N=244	(births=40	deaths=35)
#
# 	........................................................................
# main:	it=-1:	t=88
# 	species: spp_0                         N=246	(births=51	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=89
# 	species: spp_0                         N=250	(births=67	deaths=63)
#
# 	........................................................................
# main:	it=-1:	t=90
# 	species: spp_0                         N=251	(births=45	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=91
# 	species: spp_0                         N=247	(births=49	deaths=53)
#
# 	........................................................................
# main:	it=-1:	t=92
# 	species: spp_0                         N=237	(births=54	deaths=64)
#
# 	........................................................................
# main:	it=-1:	t=93
# 	species: spp_0                         N=239	(births=60	deaths=58)
#
# 	........................................................................
# main:	it=-1:	t=94
# 	species: spp_0                         N=239	(births=43	deaths=43)
#
# 	........................................................................
# main:	it=-1:	t=95
# 	species: spp_0                         N=233	(births=49	deaths=55)
#
# 	........................................................................
# main:	it=-1:	t=96
# 	species: spp_0                         N=227	(births=49	deaths=55)
#
# 	........................................................................
# main:	it=-1:	t=97
# 	species: spp_0                         N=231	(births=49	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=98
# 	species: spp_0                         N=231	(births=43	deaths=43)
#
# 	........................................................................
# main:	it=-1:	t=99
# 	species: spp_0                         N=227	(births=43	deaths=47)
#
# 	........................................................................
#
#
# now sorting and simplifying tskit tables for Species: 'spp_0'
# 	NUMBER EDGES BEFORE SIMPLIFICATION: 19640
# 	NUMBER INDIVIDS BEFORE SIMPLIFICATION: 5448
#
# 	NUMBER EDGES AFTER SIMPLIFICATION:  3966
# 	NUMBER INDIVIDS AFTER SIMPLIFICATION:  654

# %%
# Plot the results
plot_popgen(mod)

# %%
# Run the model for another 100 steps
mod.walk(100)
# Out:
# main:	it=-1:	t=100
# 	species: spp_0                         N=226	(births=48	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=101
# 	species: spp_0                         N=230	(births=42	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=102
# 	species: spp_0                         N=229	(births=45	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=103
# 	species: spp_0                         N=232	(births=51	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=104
# 	species: spp_0                         N=223	(births=36	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=105
# 	species: spp_0                         N=231	(births=48	deaths=40)
#
# 	........................................................................
# main:	it=-1:	t=106
# 	species: spp_0                         N=228	(births=33	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=107
# 	species: spp_0                         N=233	(births=50	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=108
# 	species: spp_0                         N=243	(births=39	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=109
# 	species: spp_0                         N=241	(births=39	deaths=41)
#
# 	........................................................................
# main:	it=-1:	t=110
# 	species: spp_0                         N=238	(births=54	deaths=57)
#
# 	........................................................................
# main:	it=-1:	t=111
# 	species: spp_0                         N=231	(births=52	deaths=59)
#
# 	........................................................................
# main:	it=-1:	t=112
# 	species: spp_0                         N=229	(births=42	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=113
# 	species: spp_0                         N=222	(births=33	deaths=40)
#
# 	........................................................................
# main:	it=-1:	t=114
# 	species: spp_0                         N=220	(births=36	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=115
# 	species: spp_0                         N=221	(births=33	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=116
# 	species: spp_0                         N=211	(births=33	deaths=43)
#
# 	........................................................................
# main:	it=-1:	t=117
# 	species: spp_0                         N=208	(births=34	deaths=37)
#
# 	........................................................................
# main:	it=-1:	t=118
# 	species: spp_0                         N=226	(births=47	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=119
# 	species: spp_0                         N=213	(births=43	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=120
# 	species: spp_0                         N=204	(births=41	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=121
# 	species: spp_0                         N=210	(births=40	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=122
# 	species: spp_0                         N=215	(births=38	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=123
# 	species: spp_0                         N=223	(births=51	deaths=43)
#
# 	........................................................................
# main:	it=-1:	t=124
# 	species: spp_0                         N=223	(births=53	deaths=53)
#
# 	........................................................................
# main:	it=-1:	t=125
# 	species: spp_0                         N=222	(births=37	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=126
# 	species: spp_0                         N=231	(births=50	deaths=41)
#
# 	........................................................................
# main:	it=-1:	t=127
# 	species: spp_0                         N=228	(births=33	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=128
# 	species: spp_0                         N=221	(births=48	deaths=55)
#
# 	........................................................................
# main:	it=-1:	t=129
# 	species: spp_0                         N=225	(births=36	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=130
# 	species: spp_0                         N=229	(births=51	deaths=47)
#
# 	........................................................................
# main:	it=-1:	t=131
# 	species: spp_0                         N=232	(births=49	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=132
# 	species: spp_0                         N=236	(births=43	deaths=39)
#
# 	........................................................................
# main:	it=-1:	t=133
# 	species: spp_0                         N=235	(births=47	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=134
# 	species: spp_0                         N=232	(births=50	deaths=53)
#
# 	........................................................................
# main:	it=-1:	t=135
# 	species: spp_0                         N=215	(births=51	deaths=68)
#
# 	........................................................................
# main:	it=-1:	t=136
# 	species: spp_0                         N=228	(births=40	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=137
# 	species: spp_0                         N=236	(births=54	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=138
# 	species: spp_0                         N=219	(births=47	deaths=64)
#
# 	........................................................................
# main:	it=-1:	t=139
# 	species: spp_0                         N=215	(births=33	deaths=37)
#
# 	........................................................................
# main:	it=-1:	t=140
# 	species: spp_0                         N=208	(births=43	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=141
# 	species: spp_0                         N=215	(births=43	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=142
# 	species: spp_0                         N=221	(births=39	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=143
# 	species: spp_0                         N=228	(births=47	deaths=40)
#
# 	........................................................................
# main:	it=-1:	t=144
# 	species: spp_0                         N=225	(births=46	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=145
# 	species: spp_0                         N=233	(births=52	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=146
# 	species: spp_0                         N=233	(births=46	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=147
# 	species: spp_0                         N=234	(births=31	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=148
# 	species: spp_0                         N=242	(births=54	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=149
# 	species: spp_0                         N=231	(births=40	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=150
# 	species: spp_0                         N=224	(births=47	deaths=54)
#
# 	........................................................................
# main:	it=-1:	t=151
# 	species: spp_0                         N=241	(births=42	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=152
# 	species: spp_0                         N=224	(births=41	deaths=58)
#
# 	........................................................................
# main:	it=-1:	t=153
# 	species: spp_0                         N=222	(births=54	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=154
# 	species: spp_0                         N=230	(births=57	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=155
# 	species: spp_0                         N=240	(births=40	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=156
# 	species: spp_0                         N=241	(births=39	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=157
# 	species: spp_0                         N=221	(births=53	deaths=73)
#
# 	........................................................................
# main:	it=-1:	t=158
# 	species: spp_0                         N=225	(births=49	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=159
# 	species: spp_0                         N=241	(births=50	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=160
# 	species: spp_0                         N=257	(births=68	deaths=52)
#
# 	........................................................................
# main:	it=-1:	t=161
# 	species: spp_0                         N=241	(births=49	deaths=65)
#
# 	........................................................................
# main:	it=-1:	t=162
# 	species: spp_0                         N=245	(births=53	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=163
# 	species: spp_0                         N=245	(births=50	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=164
# 	species: spp_0                         N=231	(births=64	deaths=78)
#
# 	........................................................................
# main:	it=-1:	t=165
# 	species: spp_0                         N=229	(births=42	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=166
# 	species: spp_0                         N=230	(births=53	deaths=52)
#
# 	........................................................................
# main:	it=-1:	t=167
# 	species: spp_0                         N=242	(births=45	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=168
# 	species: spp_0                         N=236	(births=43	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=169
# 	species: spp_0                         N=231	(births=44	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=170
# 	species: spp_0                         N=238	(births=47	deaths=40)
#
# 	........................................................................
# main:	it=-1:	t=171
# 	species: spp_0                         N=231	(births=52	deaths=59)
#
# 	........................................................................
# main:	it=-1:	t=172
# 	species: spp_0                         N=229	(births=43	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=173
# 	species: spp_0                         N=241	(births=45	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=174
# 	species: spp_0                         N=232	(births=47	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=175
# 	species: spp_0                         N=243	(births=44	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=176
# 	species: spp_0                         N=247	(births=48	deaths=44)
#
# 	........................................................................
# main:	it=-1:	t=177
# 	species: spp_0                         N=247	(births=46	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=178
# 	species: spp_0                         N=238	(births=41	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=179
# 	species: spp_0                         N=246	(births=41	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=180
# 	species: spp_0                         N=246	(births=50	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=181
# 	species: spp_0                         N=239	(births=51	deaths=58)
#
# 	........................................................................
# main:	it=-1:	t=182
# 	species: spp_0                         N=232	(births=49	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=183
# 	species: spp_0                         N=244	(births=48	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=184
# 	species: spp_0                         N=225	(births=50	deaths=69)
#
# 	........................................................................
# main:	it=-1:	t=185
# 	species: spp_0                         N=249	(births=50	deaths=26)
#
# 	........................................................................
# main:	it=-1:	t=186
# 	species: spp_0                         N=257	(births=56	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=187
# 	species: spp_0                         N=248	(births=53	deaths=62)
#
# 	........................................................................
# main:	it=-1:	t=188
# 	species: spp_0                         N=245	(births=58	deaths=61)
#
# 	........................................................................
# main:	it=-1:	t=189
# 	species: spp_0                         N=245	(births=56	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=190
# 	species: spp_0                         N=229	(births=44	deaths=60)
#
# 	........................................................................
# main:	it=-1:	t=191
# 	species: spp_0                         N=248	(births=42	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=192
# 	species: spp_0                         N=243	(births=49	deaths=54)
#
# 	........................................................................
# main:	it=-1:	t=193
# 	species: spp_0                         N=239	(births=52	deaths=56)
#
# 	........................................................................
# main:	it=-1:	t=194
# 	species: spp_0                         N=241	(births=52	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=195
# 	species: spp_0                         N=235	(births=53	deaths=59)
#
# 	........................................................................
# main:	it=-1:	t=196
# 	species: spp_0                         N=231	(births=38	deaths=42)
#
# 	........................................................................
# main:	it=-1:	t=197
# 	species: spp_0                         N=243	(births=57	deaths=45)
#
# 	........................................................................
# main:	it=-1:	t=198
# 	species: spp_0                         N=250	(births=54	deaths=47)
#
# 	........................................................................
# main:	it=-1:	t=199
# 	species: spp_0                         N=230	(births=38	deaths=58)
#
# 	........................................................................
#
#
# now sorting and simplifying tskit tables for Species: 'spp_0'
# 	NUMBER EDGES BEFORE SIMPLIFICATION: 22474
# 	NUMBER INDIVIDS BEFORE SIMPLIFICATION: 5262
#
# 	NUMBER EDGES AFTER SIMPLIFICATION:  4822
# 	NUMBER INDIVIDS AFTER SIMPLIFICATION:  789

# %%
plot_popgen(mod)

# %% [markdown]
# ### Challenges

# %% [markdown]
# 1. You are consulting with a conservation organization that is trying to decide whether to build (Option 1) a large, connected, single preserve or (Option 2) several, smaller, disconnected preserves. Design a simulation (or a set of simulations) to help them make their decision. Bonus challenge: try and simulate one scenario where option (1) is best and one scenario where (2) is best (Hint: think about different things you might want to conserve)
#
# 2. Wildlife corridors are a popular method for restoring connectivity between areas fragmented by human development, such as roads. Create a simulation (or a pair of simulations) that shows the effect of a wildlife corridor across a hypothetical road on genetic diversity. What happens if the corridor connects two very different environments?
#
# 3. Your friend comes to you super excited because they just analyzed their landscape genetics data on hedgehogs and found a super clear gradient in PC values that aligns with a gradient in temperature [IMAGE]. They tell you that they think this is an indication that hedgehogs are locally adapted to temperature. What do you think? Can you come up with a simulation to show your friend what else could be causing this pattern?
#
# 4. [SHOW IMAGE] try and create a simulation that matches the plot below. Bonus challenge: can you generate two different simulations that produce the same plot?
