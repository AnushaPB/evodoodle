# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import geonomics as gnx
from evodoodle import make_landscapes, edit_landscapes, init_mod, plot_popgen, draw_landscape
from gnx_params import params

# %% [markdown]
# ### 1. Draw your own landscape

# %%
# Draw your landscape carrying capacity
# When you run this chunk a pop-up will appear where you can draw on your own landscape
# Note: d sets the dimensions of your square landscape in terms of the number of cells
population_size = draw_landscape(d = 10)

# %%
# Draw your landscape connectivity
connectivity = draw_landscape(d = 10)

# %%
# Draw your environment for local adaptation
environment = draw_landscape(d = 10)

# %%
# Save your landscapes
np.savetxt('population_size.csv', population_size, delimiter=',')
np.savetxt('connectivity.csv', connectivity, delimiter=',')
np.savetxt('environment.csv', environment, delimiter=',')

# Read in landscapes
#population_size = np.loadtxt('population_size.csv', delimiter=',')
#connectivity = np.loadtxt('connectivity.csv', delimiter=',')
#environment = np.loadtxt('environment.csv', delimiter=',')

# %% [markdown]
# ### 2. Play out evolution across your landscape

# %%
# Start model
mod = init_mod(params, population_size, connectivity, environment)
# Out:
# MAKING MODEL...
#
# 	MAKING LANDSCAPE...
#
# 	MAKING COMMUNITY...
#
# 		MAKING SPECIES spp_0...
#
# 			making genomic architecture...
#
# 			making individuals...
#
# 			making movement surface...
# 				[can take a bit]
#
#
#
# No mod.burn_fn_queue was found. Running mod.reset()...
#
#
# Creating the burn-in function queue...
#
#
# Creating the main function queue...
#
#
# burn:	it=-1:	t=0
# 	species: spp_0                         N=274	(births=106	deaths=332)
#
# 	........................................................................
# burn:	it=-1:	t=1
# 	species: spp_0                         N=233	(births=65	deaths=106)
#
# 	........................................................................
# burn:	it=-1:	t=2
# 	species: spp_0                         N=212	(births=51	deaths=72)
#
# 	........................................................................
# burn:	it=-1:	t=3
# 	species: spp_0                         N=185	(births=46	deaths=73)
#
# 	........................................................................
# burn:	it=-1:	t=4
# 	species: spp_0                         N=168	(births=36	deaths=53)
#
# 	........................................................................
# burn:	it=-1:	t=5
# 	species: spp_0                         N=159	(births=36	deaths=45)
#
# 	........................................................................
# burn:	it=-1:	t=6
# 	species: spp_0                         N=147	(births=31	deaths=43)
#
# 	........................................................................
# burn:	it=-1:	t=7
# 	species: spp_0                         N=122	(births=23	deaths=48)
#
# 	........................................................................
# burn:	it=-1:	t=8
# 	species: spp_0                         N=115	(births=22	deaths=29)
#
# 	........................................................................
# burn:	it=-1:	t=9
# 	species: spp_0                         N=116	(births=20	deaths=19)
#
# 	........................................................................
# burn:	it=-1:	t=10
# 	species: spp_0                         N=111	(births=20	deaths=25)
#
# 	........................................................................
# burn:	it=-1:	t=11
# 	species: spp_0                         N=102	(births=21	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=12
# 	species: spp_0                         N=96	(births=16	deaths=22)
#
# 	........................................................................
# burn:	it=-1:	t=13
# 	species: spp_0                         N=91	(births=14	deaths=19)
#
# 	........................................................................
# burn:	it=-1:	t=14
# 	species: spp_0                         N=104	(births=21	deaths=8)
#
# 	........................................................................
# burn:	it=-1:	t=15
# 	species: spp_0                         N=110	(births=24	deaths=18)
#
# 	........................................................................
# burn:	it=-1:	t=16
# 	species: spp_0                         N=104	(births=22	deaths=28)
#
# 	........................................................................
# burn:	it=-1:	t=17
# 	species: spp_0                         N=107	(births=18	deaths=15)
#
# 	........................................................................
# burn:	it=-1:	t=18
# 	species: spp_0                         N=94	(births=15	deaths=28)
#
# 	........................................................................
# burn:	it=-1:	t=19
# 	species: spp_0                         N=100	(births=22	deaths=16)
#
# 	........................................................................
# burn:	it=-1:	t=20
# 	species: spp_0                         N=103	(births=22	deaths=19)
#
# 	........................................................................
# burn:	it=-1:	t=21
# 	species: spp_0                         N=93	(births=18	deaths=28)
#
# 	........................................................................
# burn:	it=-1:	t=22
# 	species: spp_0                         N=94	(births=18	deaths=17)
#
# 	........................................................................
# burn:	it=-1:	t=23
# 	species: spp_0                         N=93	(births=19	deaths=20)
#
# 	........................................................................
# burn:	it=-1:	t=24
# 	species: spp_0                         N=84	(births=18	deaths=27)
#
# 	........................................................................
# burn:	it=-1:	t=25
# 	species: spp_0                         N=87	(births=21	deaths=18)
#
# 	........................................................................
# burn:	it=-1:	t=26
# 	species: spp_0                         N=86	(births=15	deaths=16)
#
# 	........................................................................
# burn:	it=-1:	t=27
# 	species: spp_0                         N=84	(births=20	deaths=22)
#
# 	........................................................................
# burn:	it=-1:	t=28
# 	species: spp_0                         N=80	(births=20	deaths=24)
#
# 	........................................................................
# burn:	it=-1:	t=29
# 	species: spp_0                         N=80	(births=18	deaths=18)
#
# 	........................................................................
# burn:	it=-1:	t=30
# 	species: spp_0                         N=75	(births=7	deaths=12)
#
# 	........................................................................
# burn:	it=-1:	t=31
# 	species: spp_0                         N=76	(births=20	deaths=19)
#
# 	........................................................................
# burn:	it=-1:	t=32
# 	species: spp_0                         N=79	(births=18	deaths=15)
#
# 	........................................................................
# burn:	it=-1:	t=33
# 	species: spp_0                         N=90	(births=24	deaths=13)
#
# 	........................................................................
# burn:	it=-1:	t=34
# 	species: spp_0                         N=75	(births=23	deaths=38)
#
# 	........................................................................
# burn:	it=-1:	t=35
# 	species: spp_0                         N=81	(births=15	deaths=9)
#
# 	........................................................................
# burn:	it=-1:	t=36
# 	species: spp_0                         N=78	(births=14	deaths=17)
#
# 	........................................................................
# burn:	it=-1:	t=37
# 	species: spp_0                         N=81	(births=15	deaths=12)
#
# 	........................................................................
# burn:	it=-1:	t=38
# 	species: spp_0                         N=90	(births=18	deaths=9)
#
# 	........................................................................
# burn:	it=-1:	t=39
# 	species: spp_0                         N=99	(births=15	deaths=6)
#
# 	........................................................................
# burn:	it=-1:	t=40
# 	species: spp_0                         N=90	(births=21	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=41
# 	species: spp_0                         N=90	(births=12	deaths=12)
#
# 	........................................................................
# burn:	it=-1:	t=42
# 	species: spp_0                         N=92	(births=20	deaths=18)
#
# 	........................................................................
# burn:	it=-1:	t=43
# 	species: spp_0                         N=89	(births=24	deaths=27)
#
# 	........................................................................
# burn:	it=-1:	t=44
# 	species: spp_0                         N=95	(births=18	deaths=12)
#
# 	........................................................................
# burn:	it=-1:	t=45
# 	species: spp_0                         N=83	(births=22	deaths=34)
#
# 	........................................................................
# burn:	it=-1:	t=46
# 	species: spp_0                         N=81	(births=13	deaths=15)
#
# 	........................................................................
# burn:	it=-1:	t=47
# 	species: spp_0                         N=80	(births=13	deaths=14)
#
# 	........................................................................
# burn:	it=-1:	t=48
# 	species: spp_0                         N=84	(births=17	deaths=13)
#
# 	........................................................................
# burn:	it=-1:	t=49
# 	species: spp_0                         N=86	(births=14	deaths=12)
#
# 	........................................................................
# burn:	it=-1:	t=50
# 	species: spp_0                         N=90	(births=15	deaths=11)
#
# 	........................................................................
# burn:	it=-1:	t=51
# 	species: spp_0                         N=83	(births=17	deaths=24)
#
# 	........................................................................
# burn:	it=-1:	t=52
# 	species: spp_0                         N=88	(births=20	deaths=15)
#
# 	........................................................................
# burn:	it=-1:	t=53
# 	species: spp_0                         N=82	(births=20	deaths=26)
#
# 	........................................................................
# burn:	it=-1:	t=54
# 	species: spp_0                         N=82	(births=14	deaths=14)
#
# 	........................................................................
# burn:	it=-1:	t=55
# 	species: spp_0                         N=88	(births=19	deaths=13)
#
# 	........................................................................
# burn:	it=-1:	t=56
# 	species: spp_0                         N=92	(births=15	deaths=11)
#
# 	........................................................................
# burn:	it=-1:	t=57
# 	species: spp_0                         N=89	(births=20	deaths=23)
#
# 	........................................................................
# burn:	it=-1:	t=58
# 	species: spp_0                         N=77	(births=20	deaths=32)
#
# 	........................................................................
#
# Assigning genomes for species "spp_0"...
#
#
# Burn-in complete.

# %%
# %matplotlib inline
# Plot initial model (no selection has occurred yet)
plot_popgen(mod)

# %%
# Run the model for 100 timesteps
mod.walk(100)
# Out:
# main:	it=-1:	t=0
# 	species: spp_0                         N=75	(births=14	deaths=16)
#
# 	........................................................................
# main:	it=-1:	t=1
# 	species: spp_0                         N=79	(births=12	deaths=8)
#
# 	........................................................................
# main:	it=-1:	t=2
# 	species: spp_0                         N=77	(births=12	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=3
# 	species: spp_0                         N=84	(births=14	deaths=7)
#
# 	........................................................................
# main:	it=-1:	t=4
# 	species: spp_0                         N=83	(births=11	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=5
# 	species: spp_0                         N=82	(births=10	deaths=11)
#
# 	........................................................................
# main:	it=-1:	t=6
# 	species: spp_0                         N=79	(births=17	deaths=20)
#
# 	........................................................................
# main:	it=-1:	t=7
# 	species: spp_0                         N=82	(births=16	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=8
# 	species: spp_0                         N=66	(births=13	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=9
# 	species: spp_0                         N=69	(births=15	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=10
# 	species: spp_0                         N=71	(births=12	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=11
# 	species: spp_0                         N=70	(births=11	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=12
# 	species: spp_0                         N=74	(births=16	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=13
# 	species: spp_0                         N=75	(births=10	deaths=9)
#
# 	........................................................................
# main:	it=-1:	t=14
# 	species: spp_0                         N=74	(births=14	deaths=15)
#
# 	........................................................................
# main:	it=-1:	t=15
# 	species: spp_0                         N=68	(births=18	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=16
# 	species: spp_0                         N=70	(births=16	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=17
# 	species: spp_0                         N=70	(births=18	deaths=18)
#
# 	........................................................................
# main:	it=-1:	t=18
# 	species: spp_0                         N=65	(births=10	deaths=15)
#
# 	........................................................................
# main:	it=-1:	t=19
# 	species: spp_0                         N=63	(births=8	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=20
# 	species: spp_0                         N=66	(births=11	deaths=8)
#
# 	........................................................................
# main:	it=-1:	t=21
# 	species: spp_0                         N=61	(births=16	deaths=21)
#
# 	........................................................................
# main:	it=-1:	t=22
# 	species: spp_0                         N=67	(births=17	deaths=11)
#
# 	........................................................................
# main:	it=-1:	t=23
# 	species: spp_0                         N=74	(births=10	deaths=3)
#
# 	........................................................................
# main:	it=-1:	t=24
# 	species: spp_0                         N=75	(births=18	deaths=17)
#
# 	........................................................................
# main:	it=-1:	t=25
# 	species: spp_0                         N=73	(births=11	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=26
# 	species: spp_0                         N=75	(births=12	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=27
# 	species: spp_0                         N=68	(births=19	deaths=26)
#
# 	........................................................................
# main:	it=-1:	t=28
# 	species: spp_0                         N=57	(births=19	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=29
# 	species: spp_0                         N=55	(births=11	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=30
# 	species: spp_0                         N=62	(births=18	deaths=11)
#
# 	........................................................................
# main:	it=-1:	t=31
# 	species: spp_0                         N=69	(births=11	deaths=4)
#
# 	........................................................................
# main:	it=-1:	t=32
# 	species: spp_0                         N=70	(births=13	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=33
# 	species: spp_0                         N=74	(births=9	deaths=5)
#
# 	........................................................................
# main:	it=-1:	t=34
# 	species: spp_0                         N=71	(births=7	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=35
# 	species: spp_0                         N=62	(births=14	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=36
# 	species: spp_0                         N=62	(births=11	deaths=11)
#
# 	........................................................................
# main:	it=-1:	t=37
# 	species: spp_0                         N=59	(births=8	deaths=11)
#
# 	........................................................................
# main:	it=-1:	t=38
# 	species: spp_0                         N=58	(births=12	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=39
# 	species: spp_0                         N=57	(births=10	deaths=11)
#
# 	........................................................................
# main:	it=-1:	t=40
# 	species: spp_0                         N=57	(births=8	deaths=8)
#
# 	........................................................................
# main:	it=-1:	t=41
# 	species: spp_0                         N=59	(births=14	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=42
# 	species: spp_0                         N=65	(births=11	deaths=5)
#
# 	........................................................................
# main:	it=-1:	t=43
# 	species: spp_0                         N=61	(births=13	deaths=17)
#
# 	........................................................................
# main:	it=-1:	t=44
# 	species: spp_0                         N=55	(births=11	deaths=17)
#
# 	........................................................................
# main:	it=-1:	t=45
# 	species: spp_0                         N=57	(births=15	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=46
# 	species: spp_0                         N=57	(births=10	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=47
# 	species: spp_0                         N=58	(births=11	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=48
# 	species: spp_0                         N=61	(births=12	deaths=9)
#
# 	........................................................................
# main:	it=-1:	t=49
# 	species: spp_0                         N=67	(births=7	deaths=1)
#
# 	........................................................................
# main:	it=-1:	t=50
# 	species: spp_0                         N=74	(births=16	deaths=9)
#
# 	........................................................................
# main:	it=-1:	t=51
# 	species: spp_0                         N=73	(births=11	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=52
# 	species: spp_0                         N=64	(births=12	deaths=21)
#
# 	........................................................................
# main:	it=-1:	t=53
# 	species: spp_0                         N=69	(births=14	deaths=9)
#
# 	........................................................................
# main:	it=-1:	t=54
# 	species: spp_0                         N=74	(births=14	deaths=9)
#
# 	........................................................................
# main:	it=-1:	t=55
# 	species: spp_0                         N=73	(births=19	deaths=20)
#
# 	........................................................................
# main:	it=-1:	t=56
# 	species: spp_0                         N=67	(births=8	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=57
# 	species: spp_0                         N=66	(births=17	deaths=18)
#
# 	........................................................................
# main:	it=-1:	t=58
# 	species: spp_0                         N=72	(births=15	deaths=9)
#
# 	........................................................................
# main:	it=-1:	t=59
# 	species: spp_0                         N=65	(births=11	deaths=18)
#
# 	........................................................................
# main:	it=-1:	t=60
# 	species: spp_0                         N=74	(births=14	deaths=5)
#
# 	........................................................................
# main:	it=-1:	t=61
# 	species: spp_0                         N=82	(births=15	deaths=7)
#
# 	........................................................................
# main:	it=-1:	t=62
# 	species: spp_0                         N=75	(births=18	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=63
# 	species: spp_0                         N=82	(births=18	deaths=11)
#
# 	........................................................................
# main:	it=-1:	t=64
# 	species: spp_0                         N=81	(births=14	deaths=15)
#
# 	........................................................................
# main:	it=-1:	t=65
# 	species: spp_0                         N=81	(births=20	deaths=20)
#
# 	........................................................................
# main:	it=-1:	t=66
# 	species: spp_0                         N=85	(births=17	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=67
# 	species: spp_0                         N=74	(births=13	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=68
# 	species: spp_0                         N=58	(births=17	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=69
# 	species: spp_0                         N=62	(births=12	deaths=8)
#
# 	........................................................................
# main:	it=-1:	t=70
# 	species: spp_0                         N=65	(births=8	deaths=5)
#
# 	........................................................................
# main:	it=-1:	t=71
# 	species: spp_0                         N=63	(births=10	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=72
# 	species: spp_0                         N=66	(births=7	deaths=4)
#
# 	........................................................................
# main:	it=-1:	t=73
# 	species: spp_0                         N=67	(births=13	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=74
# 	species: spp_0                         N=65	(births=17	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=75
# 	species: spp_0                         N=64	(births=8	deaths=9)
#
# 	........................................................................
# main:	it=-1:	t=76
# 	species: spp_0                         N=56	(births=13	deaths=21)
#
# 	........................................................................
# main:	it=-1:	t=77
# 	species: spp_0                         N=51	(births=12	deaths=17)
#
# 	........................................................................
# main:	it=-1:	t=78
# 	species: spp_0                         N=53	(births=8	deaths=6)
#
# 	........................................................................
# main:	it=-1:	t=79
# 	species: spp_0                         N=62	(births=14	deaths=5)
#
# 	........................................................................
# main:	it=-1:	t=80
# 	species: spp_0                         N=68	(births=13	deaths=7)
#
# 	........................................................................
# main:	it=-1:	t=81
# 	species: spp_0                         N=70	(births=12	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=82
# 	species: spp_0                         N=68	(births=13	deaths=15)
#
# 	........................................................................
# main:	it=-1:	t=83
# 	species: spp_0                         N=63	(births=12	deaths=17)
#
# 	........................................................................
# main:	it=-1:	t=84
# 	species: spp_0                         N=64	(births=9	deaths=8)
#
# 	........................................................................
# main:	it=-1:	t=85
# 	species: spp_0                         N=72	(births=13	deaths=5)
#
# 	........................................................................
# main:	it=-1:	t=86
# 	species: spp_0                         N=73	(births=14	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=87
# 	species: spp_0                         N=66	(births=15	deaths=22)
#
# 	........................................................................
# main:	it=-1:	t=88
# 	species: spp_0                         N=66	(births=13	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=89
# 	species: spp_0                         N=61	(births=16	deaths=21)
#
# 	........................................................................
# main:	it=-1:	t=90
# 	species: spp_0                         N=61	(births=10	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=91
# 	species: spp_0                         N=62	(births=6	deaths=5)
#
# 	........................................................................
# main:	it=-1:	t=92
# 	species: spp_0                         N=55	(births=9	deaths=16)
#
# 	........................................................................
# main:	it=-1:	t=93
# 	species: spp_0                         N=63	(births=20	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=94
# 	species: spp_0                         N=67	(births=15	deaths=11)
#
# 	........................................................................
# main:	it=-1:	t=95
# 	species: spp_0                         N=59	(births=13	deaths=21)
#
# 	........................................................................
# main:	it=-1:	t=96
# 	species: spp_0                         N=61	(births=7	deaths=5)
#
# 	........................................................................
# main:	it=-1:	t=97
# 	species: spp_0                         N=69	(births=20	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=98
# 	species: spp_0                         N=60	(births=16	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=99
# 	species: spp_0                         N=63	(births=15	deaths=12)
#
# 	........................................................................
#
#
# now sorting and simplifying tskit tables for Species: 'spp_0'
# 	NUMBER EDGES BEFORE SIMPLIFICATION: 5467
# 	NUMBER INDIVIDS BEFORE SIMPLIFICATION: 1532
#
# 	NUMBER EDGES AFTER SIMPLIFICATION:  1121
# 	NUMBER INDIVIDS AFTER SIMPLIFICATION:  193

# %%
# Plot the results
plot_popgen(mod)

# %%
# Run the model for another 100 steps
mod.walk(100)
# Out:
# main:	it=-1:	t=100
# 	species: spp_0                         N=143	(births=19	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=101
# 	species: spp_0                         N=154	(births=29	deaths=18)
#
# 	........................................................................
# main:	it=-1:	t=102
# 	species: spp_0                         N=149	(births=31	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=103
# 	species: spp_0                         N=155	(births=25	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=104
# 	species: spp_0                         N=159	(births=31	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=105
# 	species: spp_0                         N=156	(births=31	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=106
# 	species: spp_0                         N=157	(births=25	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=107
# 	species: spp_0                         N=161	(births=27	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=108
# 	species: spp_0                         N=157	(births=45	deaths=49)
#
# 	........................................................................
# main:	it=-1:	t=109
# 	species: spp_0                         N=149	(births=28	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=110
# 	species: spp_0                         N=158	(births=36	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=111
# 	species: spp_0                         N=154	(births=27	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=112
# 	species: spp_0                         N=157	(births=30	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=113
# 	species: spp_0                         N=159	(births=32	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=114
# 	species: spp_0                         N=150	(births=24	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=115
# 	species: spp_0                         N=144	(births=29	deaths=35)
#
# 	........................................................................
# main:	it=-1:	t=116
# 	species: spp_0                         N=152	(births=30	deaths=22)
#
# 	........................................................................
# main:	it=-1:	t=117
# 	species: spp_0                         N=153	(births=28	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=118
# 	species: spp_0                         N=150	(births=30	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=119
# 	species: spp_0                         N=140	(births=28	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=120
# 	species: spp_0                         N=140	(births=24	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=121
# 	species: spp_0                         N=145	(births=32	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=122
# 	species: spp_0                         N=151	(births=35	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=123
# 	species: spp_0                         N=160	(births=42	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=124
# 	species: spp_0                         N=173	(births=41	deaths=28)
#
# 	........................................................................
# main:	it=-1:	t=125
# 	species: spp_0                         N=171	(births=31	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=126
# 	species: spp_0                         N=164	(births=39	deaths=46)
#
# 	........................................................................
# main:	it=-1:	t=127
# 	species: spp_0                         N=165	(births=37	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=128
# 	species: spp_0                         N=157	(births=25	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=129
# 	species: spp_0                         N=149	(births=28	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=130
# 	species: spp_0                         N=164	(births=36	deaths=21)
#
# 	........................................................................
# main:	it=-1:	t=131
# 	species: spp_0                         N=166	(births=29	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=132
# 	species: spp_0                         N=175	(births=40	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=133
# 	species: spp_0                         N=171	(births=30	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=134
# 	species: spp_0                         N=169	(births=35	deaths=37)
#
# 	........................................................................
# main:	it=-1:	t=135
# 	species: spp_0                         N=160	(births=30	deaths=39)
#
# 	........................................................................
# main:	it=-1:	t=136
# 	species: spp_0                         N=162	(births=23	deaths=21)
#
# 	........................................................................
# main:	it=-1:	t=137
# 	species: spp_0                         N=155	(births=29	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=138
# 	species: spp_0                         N=159	(births=29	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=139
# 	species: spp_0                         N=162	(births=24	deaths=21)
#
# 	........................................................................
# main:	it=-1:	t=140
# 	species: spp_0                         N=162	(births=39	deaths=39)
#
# 	........................................................................
# main:	it=-1:	t=141
# 	species: spp_0                         N=162	(births=31	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=142
# 	species: spp_0                         N=154	(births=42	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=143
# 	species: spp_0                         N=158	(births=30	deaths=26)
#
# 	........................................................................
# main:	it=-1:	t=144
# 	species: spp_0                         N=168	(births=33	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=145
# 	species: spp_0                         N=161	(births=30	deaths=37)
#
# 	........................................................................
# main:	it=-1:	t=146
# 	species: spp_0                         N=161	(births=33	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=147
# 	species: spp_0                         N=165	(births=28	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=148
# 	species: spp_0                         N=157	(births=28	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=149
# 	species: spp_0                         N=158	(births=29	deaths=28)
#
# 	........................................................................
# main:	it=-1:	t=150
# 	species: spp_0                         N=153	(births=27	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=151
# 	species: spp_0                         N=149	(births=35	deaths=39)
#
# 	........................................................................
# main:	it=-1:	t=152
# 	species: spp_0                         N=157	(births=30	deaths=22)
#
# 	........................................................................
# main:	it=-1:	t=153
# 	species: spp_0                         N=163	(births=28	deaths=22)
#
# 	........................................................................
# main:	it=-1:	t=154
# 	species: spp_0                         N=159	(births=28	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=155
# 	species: spp_0                         N=143	(births=25	deaths=41)
#
# 	........................................................................
# main:	it=-1:	t=156
# 	species: spp_0                         N=147	(births=32	deaths=28)
#
# 	........................................................................
# main:	it=-1:	t=157
# 	species: spp_0                         N=147	(births=27	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=158
# 	species: spp_0                         N=153	(births=26	deaths=20)
#
# 	........................................................................
# main:	it=-1:	t=159
# 	species: spp_0                         N=150	(births=21	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=160
# 	species: spp_0                         N=151	(births=30	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=161
# 	species: spp_0                         N=160	(births=33	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=162
# 	species: spp_0                         N=155	(births=27	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=163
# 	species: spp_0                         N=160	(births=34	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=164
# 	species: spp_0                         N=165	(births=31	deaths=26)
#
# 	........................................................................
# main:	it=-1:	t=165
# 	species: spp_0                         N=154	(births=26	deaths=37)
#
# 	........................................................................
# main:	it=-1:	t=166
# 	species: spp_0                         N=150	(births=32	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=167
# 	species: spp_0                         N=154	(births=39	deaths=35)
#
# 	........................................................................
# main:	it=-1:	t=168
# 	species: spp_0                         N=168	(births=31	deaths=17)
#
# 	........................................................................
# main:	it=-1:	t=169
# 	species: spp_0                         N=161	(births=25	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=170
# 	species: spp_0                         N=155	(births=24	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=171
# 	species: spp_0                         N=157	(births=27	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=172
# 	species: spp_0                         N=148	(births=33	deaths=42)
#
# 	........................................................................
# main:	it=-1:	t=173
# 	species: spp_0                         N=152	(births=25	deaths=21)
#
# 	........................................................................
# main:	it=-1:	t=174
# 	species: spp_0                         N=153	(births=33	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=175
# 	species: spp_0                         N=148	(births=33	deaths=38)
#
# 	........................................................................
# main:	it=-1:	t=176
# 	species: spp_0                         N=155	(births=22	deaths=15)
#
# 	........................................................................
# main:	it=-1:	t=177
# 	species: spp_0                         N=137	(births=33	deaths=51)
#
# 	........................................................................
# main:	it=-1:	t=178
# 	species: spp_0                         N=156	(births=32	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=179
# 	species: spp_0                         N=158	(births=36	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=180
# 	species: spp_0                         N=154	(births=23	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=181
# 	species: spp_0                         N=159	(births=33	deaths=28)
#
# 	........................................................................
# main:	it=-1:	t=182
# 	species: spp_0                         N=164	(births=34	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=183
# 	species: spp_0                         N=162	(births=32	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=184
# 	species: spp_0                         N=159	(births=37	deaths=40)
#
# 	........................................................................
# main:	it=-1:	t=185
# 	species: spp_0                         N=164	(births=36	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=186
# 	species: spp_0                         N=161	(births=24	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=187
# 	species: spp_0                         N=162	(births=33	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=188
# 	species: spp_0                         N=161	(births=29	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=189
# 	species: spp_0                         N=152	(births=20	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=190
# 	species: spp_0                         N=160	(births=31	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=191
# 	species: spp_0                         N=167	(births=37	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=192
# 	species: spp_0                         N=156	(births=36	deaths=47)
#
# 	........................................................................
# main:	it=-1:	t=193
# 	species: spp_0                         N=156	(births=25	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=194
# 	species: spp_0                         N=160	(births=38	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=195
# 	species: spp_0                         N=172	(births=35	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=196
# 	species: spp_0                         N=178	(births=41	deaths=35)
#
# 	........................................................................
# main:	it=-1:	t=197
# 	species: spp_0                         N=166	(births=36	deaths=48)
#
# 	........................................................................
# main:	it=-1:	t=198
# 	species: spp_0                         N=170	(births=33	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=199
# 	species: spp_0                         N=184	(births=41	deaths=27)
#
# 	........................................................................
#
#
# now sorting and simplifying tskit tables for Species: 'spp_0'
# 	NUMBER EDGES BEFORE SIMPLIFICATION: 14889
# 	NUMBER INDIVIDS BEFORE SIMPLIFICATION: 3528
#
# 	NUMBER EDGES AFTER SIMPLIFICATION:  3516
# 	NUMBER INDIVIDS AFTER SIMPLIFICATION:  565

# %%
plot_popgen(mod)

# %% [markdown]
# ### Challenges

# %% [markdown]
# 1. You are consulting with a conservation organization that is trying to decide whether to build (Option 1) a large, connected, single preserve or (Option 2) several, smaller, disconnected preserves. Design a simulation (or a set of simulations) to help them make their decision. Bonus challenge: try and simulate one scenario where option (1) is best and one scenario where (2) is best (Hint: think about different things you might want to conserve)
#
# 2. [SHOW IMAGE] try and create a simulation that matches the plot below. Bonus challenge: can you generate two different simulations that produce the same plot?
#
# 3.
