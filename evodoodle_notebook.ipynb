# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import geonomics as gnx
import evodoodle as evo
from gnx_params import params
# Out:
# NOTE: Module 'pykrige' not found. Yosemite demo 3d plots cannot be produced.
# pygame 2.6.0 (SDL 2.28.4, Python 3.6.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### 1. Draw your own landscape

# %%
# Draw your landscape carrying capacity
# When you run this chunk a pop-up will appear where you can draw on your own landscape
# Note: d sets the dimensions of your square landscape in terms of the number of cells
population_size = evo.draw_landscape(d = 10)

# %%
# Draw your landscape connectivity
connectivity = evo.draw_landscape(d = 10)

# %%
# Draw your environment for local adaptation
environment = evo.draw_landscape(d = 10)

# %%
# %matplotlib inline
# You can plot all your landscapes using plot_landscapes()
evo.plot_landscapes(population_size, connectivity, environment)

# %%
# If you want to change something, you can edit your landscapes using the edit_landscape() function
environment = evo.edit_landscape(environment)

# %%
# Finally, you can optionally save your landscapes
np.savetxt('population_size.csv', population_size, delimiter=',')
np.savetxt('connectivity.csv', connectivity, delimiter=',')
np.savetxt('environment.csv', environment, delimiter=',')

# Read in landscapes
#population_size = np.loadtxt('population_size.csv', delimiter=',')
#connectivity = np.loadtxt('connectivity.csv', delimiter=',')
#environment = np.loadtxt('environment.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-7-70e08c5a0fb6> in <module>()
#       1 # Finally, you can optionally save your landscapes
# ----> 2 np.savetxt('population_size.csv', population_size, delimiter=',')
#       3 np.savetxt('connectivity.csv', connectivity, delimiter=',')
#       4 np.savetxt('environment.csv', environment, delimiter=',')
#       5
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1355     if _is_string_like(fname):
#    1356         # datasource doesn't support creating a new file ...
# -> 1357         open(fname, 'wt').close()
#    1358         fh = np.lib._datasource.open(fname, 'wt', encoding=encoding)
#    1359         own_fh = True
#
# PermissionError: [Errno 13] Permission denied: 'population_size.csv'

# %% [markdown]
# ### 2. Play out evolution across your landscape

# %%
# Start model
mod = evo.init_mod(params, population_size, connectivity, environment)
# Out:
# MAKING MODEL...
#
# 	MAKING LANDSCAPE...
#
# 	MAKING COMMUNITY...
#
# 		MAKING SPECIES spp_0...
#
# 			making genomic architecture...
#
# 			making individuals...
#
# 			making movement surface...
# 				[can take a bit]
#
#
#
# No mod.burn_fn_queue was found. Running mod.reset()...
#
#
# Creating the burn-in function queue...
#
#
# Creating the main function queue...
#
#
# burn:	it=-1:	t=0
# 	species: spp_0                         N=358	(births=81	deaths=223)
#
# 	........................................................................
# burn:	it=-1:	t=1
# 	species: spp_0                         N=305	(births=67	deaths=120)
#
# 	........................................................................
# burn:	it=-1:	t=2
# 	species: spp_0                         N=261	(births=66	deaths=110)
#
# 	........................................................................
# burn:	it=-1:	t=3
# 	species: spp_0                         N=247	(births=58	deaths=72)
#
# 	........................................................................
# burn:	it=-1:	t=4
# 	species: spp_0                         N=215	(births=41	deaths=73)
#
# 	........................................................................
# burn:	it=-1:	t=5
# 	species: spp_0                         N=196	(births=35	deaths=54)
#
# 	........................................................................
# burn:	it=-1:	t=6
# 	species: spp_0                         N=155	(births=33	deaths=74)
#
# 	........................................................................
# burn:	it=-1:	t=7
# 	species: spp_0                         N=147	(births=29	deaths=37)
#
# 	........................................................................
# burn:	it=-1:	t=8
# 	species: spp_0                         N=142	(births=23	deaths=28)
#
# 	........................................................................
# burn:	it=-1:	t=9
# 	species: spp_0                         N=141	(births=33	deaths=34)
#
# 	........................................................................
# burn:	it=-1:	t=10
# 	species: spp_0                         N=139	(births=32	deaths=34)
#
# 	........................................................................
# burn:	it=-1:	t=11
# 	species: spp_0                         N=137	(births=22	deaths=24)
#
# 	........................................................................
# burn:	it=-1:	t=12
# 	species: spp_0                         N=138	(births=27	deaths=26)
#
# 	........................................................................
# burn:	it=-1:	t=13
# 	species: spp_0                         N=140	(births=25	deaths=23)
#
# 	........................................................................
# burn:	it=-1:	t=14
# 	species: spp_0                         N=144	(births=34	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=15
# 	species: spp_0                         N=151	(births=35	deaths=28)
#
# 	........................................................................
# burn:	it=-1:	t=16
# 	species: spp_0                         N=150	(births=29	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=17
# 	species: spp_0                         N=144	(births=31	deaths=37)
#
# 	........................................................................
# burn:	it=-1:	t=18
# 	species: spp_0                         N=143	(births=23	deaths=24)
#
# 	........................................................................
# burn:	it=-1:	t=19
# 	species: spp_0                         N=153	(births=33	deaths=23)
#
# 	........................................................................
# burn:	it=-1:	t=20
# 	species: spp_0                         N=146	(births=26	deaths=33)
#
# 	........................................................................
# burn:	it=-1:	t=21
# 	species: spp_0                         N=139	(births=24	deaths=31)
#
# 	........................................................................
# burn:	it=-1:	t=22
# 	species: spp_0                         N=130	(births=30	deaths=39)
#
# 	........................................................................
# burn:	it=-1:	t=23
# 	species: spp_0                         N=136	(births=25	deaths=19)
#
# 	........................................................................
# burn:	it=-1:	t=24
# 	species: spp_0                         N=139	(births=34	deaths=31)
#
# 	........................................................................
# burn:	it=-1:	t=25
# 	species: spp_0                         N=130	(births=21	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=26
# 	species: spp_0                         N=140	(births=34	deaths=24)
#
# 	........................................................................
# burn:	it=-1:	t=27
# 	species: spp_0                         N=133	(births=19	deaths=26)
#
# 	........................................................................
# burn:	it=-1:	t=28
# 	species: spp_0                         N=130	(births=29	deaths=32)
#
# 	........................................................................
# burn:	it=-1:	t=29
# 	species: spp_0                         N=131	(births=24	deaths=23)
#
# 	........................................................................
# burn:	it=-1:	t=30
# 	species: spp_0                         N=133	(births=22	deaths=20)
#
# 	........................................................................
# burn:	it=-1:	t=31
# 	species: spp_0                         N=136	(births=30	deaths=27)
#
# 	........................................................................
# burn:	it=-1:	t=32
# 	species: spp_0                         N=139	(births=28	deaths=25)
#
# 	........................................................................
# burn:	it=-1:	t=33
# 	species: spp_0                         N=147	(births=23	deaths=15)
#
# 	........................................................................
# burn:	it=-1:	t=34
# 	species: spp_0                         N=146	(births=30	deaths=31)
#
# 	........................................................................
# burn:	it=-1:	t=35
# 	species: spp_0                         N=139	(births=27	deaths=34)
#
# 	........................................................................
# burn:	it=-1:	t=36
# 	species: spp_0                         N=144	(births=29	deaths=24)
#
# 	........................................................................
# burn:	it=-1:	t=37
# 	species: spp_0                         N=136	(births=29	deaths=37)
#
# 	........................................................................
# burn:	it=-1:	t=38
# 	species: spp_0                         N=135	(births=29	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=39
# 	species: spp_0                         N=143	(births=33	deaths=25)
#
# 	........................................................................
# /home/anushabishop/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:846: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# /home/anushabishop/anaconda3/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1510: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# burn:	it=-1:	t=40
# 	species: spp_0                         N=151	(births=31	deaths=23)
#
# 	........................................................................
# burn:	it=-1:	t=41
# 	species: spp_0                         N=151	(births=27	deaths=27)
#
# 	........................................................................
# burn:	it=-1:	t=42
# 	species: spp_0                         N=138	(births=28	deaths=41)
#
# 	........................................................................
# burn:	it=-1:	t=43
# 	species: spp_0                         N=142	(births=27	deaths=23)
#
# 	........................................................................
# burn:	it=-1:	t=44
# 	species: spp_0                         N=161	(births=28	deaths=9)
#
# 	........................................................................
# burn:	it=-1:	t=45
# 	species: spp_0                         N=143	(births=27	deaths=45)
#
# 	........................................................................
# burn:	it=-1:	t=46
# 	species: spp_0                         N=140	(births=23	deaths=26)
#
# 	........................................................................
# burn:	it=-1:	t=47
# 	species: spp_0                         N=131	(births=28	deaths=37)
#
# 	........................................................................
# burn:	it=-1:	t=48
# 	species: spp_0                         N=130	(births=35	deaths=36)
#
# 	........................................................................
# burn:	it=-1:	t=49
# 	species: spp_0                         N=137	(births=22	deaths=15)
#
# 	........................................................................
# burn:	it=-1:	t=50
# 	species: spp_0                         N=138	(births=27	deaths=26)
#
# 	........................................................................
# burn:	it=-1:	t=51
# 	species: spp_0                         N=133	(births=29	deaths=34)
#
# 	........................................................................
# burn:	it=-1:	t=52
# 	species: spp_0                         N=134	(births=31	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=53
# 	species: spp_0                         N=131	(births=27	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=54
# 	species: spp_0                         N=130	(births=29	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=55
# 	species: spp_0                         N=118	(births=24	deaths=36)
#
# 	........................................................................
# burn:	it=-1:	t=56
# 	species: spp_0                         N=123	(births=29	deaths=24)
#
# 	........................................................................
# burn:	it=-1:	t=57
# 	species: spp_0                         N=135	(births=26	deaths=14)
#
# 	........................................................................
# burn:	it=-1:	t=58
# 	species: spp_0                         N=135	(births=29	deaths=29)
#
# 	........................................................................
# burn:	it=-1:	t=59
# 	species: spp_0                         N=133	(births=29	deaths=31)
#
# 	........................................................................
# burn:	it=-1:	t=60
# 	species: spp_0                         N=132	(births=21	deaths=22)
#
# 	........................................................................
# burn:	it=-1:	t=61
# 	species: spp_0                         N=133	(births=28	deaths=27)
#
# 	........................................................................
# burn:	it=-1:	t=62
# 	species: spp_0                         N=143	(births=33	deaths=23)
#
# 	........................................................................
# burn:	it=-1:	t=63
# 	species: spp_0                         N=144	(births=31	deaths=30)
#
# 	........................................................................
# burn:	it=-1:	t=64
# 	species: spp_0                         N=135	(births=32	deaths=41)
#
# 	........................................................................
# burn:	it=-1:	t=65
# 	species: spp_0                         N=139	(births=28	deaths=24)
#
# 	........................................................................
# burn:	it=-1:	t=66
# 	species: spp_0                         N=128	(births=22	deaths=33)
#
# 	........................................................................
# burn:	it=-1:	t=67
# 	species: spp_0                         N=136	(births=22	deaths=14)
#
# 	........................................................................
# burn:	it=-1:	t=68
# 	species: spp_0                         N=138	(births=27	deaths=25)
#
# 	........................................................................
# burn:	it=-1:	t=69
# 	species: spp_0                         N=145	(births=28	deaths=21)
#
# 	........................................................................
#
# Assigning genomes for species "spp_0"...
#
#
# Burn-in complete.

# %%
# Plot initial model (no selection has occurred yet)
evo.plot_popgen(mod)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-b21ea496df70> in <module>()
#       1 # Plot initial model (no selection has occurred yet)
# ----> 2 evo.plot_popgen(mod)
#
# /mnt/c/Users/Anusha/Documents/GitHub/evodoodle/evodoodle.py in plot_popgen(mod, lyr_num)
#     310
#     311     # Plot the PCA on the first subplot
# --> 312     plot_PCA(mod, ax=ax1)
#     313
#     314     # Plot the PCA map on the second subplot
#
# /mnt/c/Users/Anusha/Documents/GitHub/evodoodle/evodoodle.py in plot_PCA(mod, ax)
#     202     figsize = 6
#     203     species = mod.comm[0]
# --> 204     speciome = np.mean(species._get_genotypes(), axis=2)
#     205     pca = PCA(n_components=3)
#     206     PCs = pca.fit_transform(speciome)
#
# ~/anaconda3/lib/python3.6/site-packages/geonomics/structs/species.py in _get_genotypes(self, loci, individs, biallelic, as_dict)
#    1416             #                               ts.haplotypes()) if n in samples]
#    1417             haps_dict = {s:h for s, h in zip(ts.samples(), ts.haplotypes())}
# -> 1418             haps = [np.int8([*haps_dict[s]]) for s in samples_to_keep]
#    1419
#    1420             # get the genotypes by combining each consecutive group
#
# ~/anaconda3/lib/python3.6/site-packages/geonomics/structs/species.py in <listcomp>(.0)
#    1416             #                               ts.haplotypes()) if n in samples]
#    1417             haps_dict = {s:h for s, h in zip(ts.samples(), ts.haplotypes())}
# -> 1418             haps = [np.int8([*haps_dict[s]]) for s in samples_to_keep]
#    1419
#    1420             # get the genotypes by combining each consecutive group
#
# ValueError: invalid literal for int() with base 10: '-'

# %%
# Run the model for 100 timesteps
mod.walk(100)
# Out:
# main:	it=-1:	t=5
# 	species: spp_0                         N=115	(births=29	deaths=50)
#
# 	........................................................................
# main:	it=-1:	t=6
# 	species: spp_0                         N=107	(births=25	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=7
# 	species: spp_0                         N=113	(births=20	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=8
# 	species: spp_0                         N=119	(births=26	deaths=20)
#
# 	........................................................................
# main:	it=-1:	t=9
# 	species: spp_0                         N=116	(births=26	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=10
# 	species: spp_0                         N=109	(births=25	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=11
# 	species: spp_0                         N=110	(births=20	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=12
# 	species: spp_0                         N=107	(births=26	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=13
# 	species: spp_0                         N=106	(births=28	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=14
# 	species: spp_0                         N=105	(births=18	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=15
# 	species: spp_0                         N=111	(births=21	deaths=15)
#
# 	........................................................................
# main:	it=-1:	t=16
# 	species: spp_0                         N=118	(births=20	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=17
# 	species: spp_0                         N=124	(births=24	deaths=18)
#
# 	........................................................................
# main:	it=-1:	t=18
# 	species: spp_0                         N=118	(births=25	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=19
# 	species: spp_0                         N=107	(births=28	deaths=39)
#
# 	........................................................................
# main:	it=-1:	t=20
# 	species: spp_0                         N=109	(births=26	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=21
# 	species: spp_0                         N=116	(births=25	deaths=18)
#
# 	........................................................................
# main:	it=-1:	t=22
# 	species: spp_0                         N=116	(births=20	deaths=20)
#
# 	........................................................................
# main:	it=-1:	t=23
# 	species: spp_0                         N=112	(births=26	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=24
# 	species: spp_0                         N=108	(births=19	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=25
# 	species: spp_0                         N=106	(births=22	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=26
# 	species: spp_0                         N=91	(births=26	deaths=41)
#
# 	........................................................................
# main:	it=-1:	t=27
# 	species: spp_0                         N=86	(births=13	deaths=18)
#
# 	........................................................................
# main:	it=-1:	t=28
# 	species: spp_0                         N=90	(births=12	deaths=8)
#
# 	........................................................................
# main:	it=-1:	t=29
# 	species: spp_0                         N=103	(births=24	deaths=11)
#
# 	........................................................................
# main:	it=-1:	t=30
# 	species: spp_0                         N=98	(births=11	deaths=16)
#
# 	........................................................................
# main:	it=-1:	t=31
# 	species: spp_0                         N=98	(births=25	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=32
# 	species: spp_0                         N=90	(births=15	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=33
# 	species: spp_0                         N=98	(births=20	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=34
# 	species: spp_0                         N=97	(births=19	deaths=20)
#
# 	........................................................................
# main:	it=-1:	t=35
# 	species: spp_0                         N=100	(births=16	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=36
# 	species: spp_0                         N=93	(births=11	deaths=18)
#
# 	........................................................................
# main:	it=-1:	t=37
# 	species: spp_0                         N=95	(births=16	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=38
# 	species: spp_0                         N=93	(births=16	deaths=18)
#
# 	........................................................................
# main:	it=-1:	t=39
# 	species: spp_0                         N=94	(births=16	deaths=15)
#
# 	........................................................................
# main:	it=-1:	t=40
# 	species: spp_0                         N=95	(births=20	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=41
# 	species: spp_0                         N=101	(births=20	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=42
# 	species: spp_0                         N=98	(births=23	deaths=26)
#
# 	........................................................................
# main:	it=-1:	t=43
# 	species: spp_0                         N=97	(births=25	deaths=26)
#
# 	........................................................................
# main:	it=-1:	t=44
# 	species: spp_0                         N=103	(births=16	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=45
# 	species: spp_0                         N=112	(births=23	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=46
# 	species: spp_0                         N=109	(births=26	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=47
# 	species: spp_0                         N=107	(births=29	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=48
# 	species: spp_0                         N=103	(births=22	deaths=26)
#
# 	........................................................................
# main:	it=-1:	t=49
# 	species: spp_0                         N=106	(births=22	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=50
# 	species: spp_0                         N=112	(births=19	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=51
# 	species: spp_0                         N=106	(births=25	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=52
# 	species: spp_0                         N=111	(births=18	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=53
# 	species: spp_0                         N=115	(births=14	deaths=10)
#
# 	........................................................................
# main:	it=-1:	t=54
# 	species: spp_0                         N=115	(births=31	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=55
# 	species: spp_0                         N=116	(births=18	deaths=17)
#
# 	........................................................................
# main:	it=-1:	t=56
# 	species: spp_0                         N=120	(births=27	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=57
# 	species: spp_0                         N=117	(births=29	deaths=32)
#
# 	........................................................................
# main:	it=-1:	t=58
# 	species: spp_0                         N=111	(births=24	deaths=30)
#
# 	........................................................................
# main:	it=-1:	t=59
# 	species: spp_0                         N=115	(births=23	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=60
# 	species: spp_0                         N=112	(births=28	deaths=31)
#
# 	........................................................................
# main:	it=-1:	t=61
# 	species: spp_0                         N=106	(births=22	deaths=28)
#
# 	........................................................................
# main:	it=-1:	t=62
# 	species: spp_0                         N=106	(births=17	deaths=17)
#
# 	........................................................................
# main:	it=-1:	t=63
# 	species: spp_0                         N=117	(births=23	deaths=12)
#
# 	........................................................................
# main:	it=-1:	t=64
# 	species: spp_0                         N=116	(births=24	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=65
# 	species: spp_0                         N=119	(births=23	deaths=20)
#
# 	........................................................................
# main:	it=-1:	t=66
# 	species: spp_0                         N=113	(births=20	deaths=26)
#
# 	........................................................................
# main:	it=-1:	t=67
# 	species: spp_0                         N=103	(births=24	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=68
# 	species: spp_0                         N=103	(births=15	deaths=15)
#
# 	........................................................................
# main:	it=-1:	t=69
# 	species: spp_0                         N=105	(births=21	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=70
# 	species: spp_0                         N=103	(births=26	deaths=28)
#
# 	........................................................................
# main:	it=-1:	t=71
# 	species: spp_0                         N=105	(births=18	deaths=16)
#
# 	........................................................................
# main:	it=-1:	t=72
# 	species: spp_0                         N=112	(births=26	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=73
# 	species: spp_0                         N=111	(births=21	deaths=22)
#
# 	........................................................................
# main:	it=-1:	t=74
# 	species: spp_0                         N=107	(births=21	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=75
# 	species: spp_0                         N=100	(births=16	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=76
# 	species: spp_0                         N=103	(births=17	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=77
# 	species: spp_0                         N=102	(births=21	deaths=22)
#
# 	........................................................................
# main:	it=-1:	t=78
# 	species: spp_0                         N=109	(births=21	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=79
# 	species: spp_0                         N=115	(births=29	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=80
# 	species: spp_0                         N=121	(births=22	deaths=16)
#
# 	........................................................................
# main:	it=-1:	t=81
# 	species: spp_0                         N=129	(births=25	deaths=17)
#
# 	........................................................................
# main:	it=-1:	t=82
# 	species: spp_0                         N=127	(births=31	deaths=33)
#
# 	........................................................................
# main:	it=-1:	t=83
# 	species: spp_0                         N=126	(births=25	deaths=26)
#
# 	........................................................................
# main:	it=-1:	t=84
# 	species: spp_0                         N=114	(births=24	deaths=36)
#
# 	........................................................................
# main:	it=-1:	t=85
# 	species: spp_0                         N=116	(births=16	deaths=14)
#
# 	........................................................................
# main:	it=-1:	t=86
# 	species: spp_0                         N=124	(births=30	deaths=22)
#
# 	........................................................................
# main:	it=-1:	t=87
# 	species: spp_0                         N=120	(births=16	deaths=20)
#
# 	........................................................................
# main:	it=-1:	t=88
# 	species: spp_0                         N=109	(births=18	deaths=29)
#
# 	........................................................................
# main:	it=-1:	t=89
# 	species: spp_0                         N=115	(births=22	deaths=16)
#
# 	........................................................................
# main:	it=-1:	t=90
# 	species: spp_0                         N=118	(births=16	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=91
# 	species: spp_0                         N=117	(births=22	deaths=23)
#
# 	........................................................................
# main:	it=-1:	t=92
# 	species: spp_0                         N=120	(births=27	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=93
# 	species: spp_0                         N=123	(births=25	deaths=22)
#
# 	........................................................................
# main:	it=-1:	t=94
# 	species: spp_0                         N=125	(births=21	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=95
# 	species: spp_0                         N=122	(births=24	deaths=27)
#
# 	........................................................................
# main:	it=-1:	t=96
# 	species: spp_0                         N=108	(births=20	deaths=34)
#
# 	........................................................................
# main:	it=-1:	t=97
# 	species: spp_0                         N=113	(births=18	deaths=13)
#
# 	........................................................................
# main:	it=-1:	t=98
# 	species: spp_0                         N=119	(births=25	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=99
# 	species: spp_0                         N=121	(births=27	deaths=25)
#
# 	........................................................................
#
#
# now sorting and simplifying tskit tables for Species: 'spp_0'
# 	NUMBER EDGES BEFORE SIMPLIFICATION: 21771768
# 	NUMBER INDIVIDS BEFORE SIMPLIFICATION: 2406
#
# 	NUMBER EDGES AFTER SIMPLIFICATION:  2343486
# 	NUMBER INDIVIDS AFTER SIMPLIFICATION:  637
#
# main:	it=-1:	t=100
# 	species: spp_0                         N=117	(births=24	deaths=28)
#
# 	........................................................................
# main:	it=-1:	t=101
# 	species: spp_0                         N=118	(births=26	deaths=25)
#
# 	........................................................................
# main:	it=-1:	t=102
# 	species: spp_0                         N=116	(births=22	deaths=24)
#
# 	........................................................................
# main:	it=-1:	t=103
# 	species: spp_0                         N=115	(births=18	deaths=19)
#
# 	........................................................................
# main:	it=-1:	t=104
# 	species: spp_0                         N=115	(births=24	deaths=24)
#
# 	........................................................................

# %%
# Plot the results
evo.plot_popgen(mod)

# %%
# Run the model for another 100 steps
mod.walk(100)
# Out:
# main:	it=-1:	t=0
# 	species: spp_0                         N=1397	(births=292	deaths=365)
#
# 	........................................................................
# main:	it=-1:	t=1
# 	species: spp_0                         N=1377	(births=264	deaths=284)
#
# 	........................................................................
# main:	it=-1:	t=2
# 	species: spp_0                         N=1399	(births=280	deaths=258)
#
# 	........................................................................
# main:	it=-1:	t=3
# 	species: spp_0                         N=1396	(births=280	deaths=283)
#
# 	........................................................................
# main:	it=-1:	t=4
# 	species: spp_0                         N=1407	(births=261	deaths=250)
#
# 	........................................................................
# main:	it=-1:	t=5
# 	species: spp_0                         N=1433	(births=276	deaths=250)
#
# 	........................................................................
# main:	it=-1:	t=6
# 	species: spp_0                         N=1416	(births=322	deaths=339)
#
# 	........................................................................
# main:	it=-1:	t=7
# 	species: spp_0                         N=1407	(births=279	deaths=288)
#
# 	........................................................................
# main:	it=-1:	t=8
# 	species: spp_0                         N=1408	(births=271	deaths=270)
#
# 	........................................................................
# main:	it=-1:	t=9
# 	species: spp_0                         N=1431	(births=248	deaths=225)
#
# 	........................................................................

# %%
plot_popgen(mod)

# %% [markdown]
# ### Challenges

# %% [markdown]
# 1. You are consulting with a conservation organization that is trying to decide whether to build (Option 1) a large, connected, single preserve or (Option 2) several, smaller, disconnected preserves. Design a simulation (or a set of simulations) to help them make their decision. Bonus challenge: try and simulate one scenario where option (1) is best and one scenario where (2) is best (Hint: think about different things you might want to conserve)
#
# 2. Wildlife corridors are a popular method for restoring connectivity between areas fragmented by human development, such as roads. Create a simulation (or a pair of simulations) that shows the effect of a wildlife corridor across a hypothetical road on genetic diversity. What happens if the corridor connects two very different environments?
#
# 3. Your friend comes to you super excited because they just analyzed their landscape genetics data on hedgehogs and found a super clear gradient in PC values that aligns with a gradient in temperature [IMAGE]. They tell you that they think this is an indication that hedgehogs are locally adapted to temperature. What do you think? Can you come up with a simulation to show your friend what else could be causing this pattern?
#
# 4. [SHOW IMAGE] try and create a simulation that matches the plot below. Bonus challenge: can you generate two different simulations that produce the same plot?
